# %% [markdown]
# <a href="https://colab.research.google.com/github/pierre700/BeerGamePRT20232024/blob/main/FSL_Beginning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# from torch.utils.data import Dataset, DataLoader, random_split
# from torchvision import models, transforms
# import cv2
# from PIL import Image
# import os
#
# # Define the image transformations
# transform = transforms.Compose([
#     transforms.ToPILImage(),
#     transforms.Resize((224, 224)),
#     transforms.ToTensor(),
#
# ])
#
# # Define the Siamese Network
# class SiameseNetwork(nn.Module):
#     def __init__(self):
#         super(SiameseNetwork, self).__init__()
#         self.resnet = models.resnet18(weights='IMAGENET1K_V1')
#
#         # Freeze all layers except the classifier
#         for param in self.resnet.parameters():
#             param.requires_grad = False
#
#         # Modify the fully connected layer
#         self.resnet.fc = nn.Linear(self.resnet.fc.in_features, 512)
#
#     def forward_one(self, x):
#         x = self.resnet(x)
#         return x
#
#     def forward(self, input1, input2):
#         output1 = self.forward_one(input1)
#         output2 = self.forward_one(input2)
#         return output1, output2
#
# # Define the dataset for image pairs
# class ImagePairDataset(Dataset):
#     def __init__(self, image_dir, shots_dir, transform=None):
#         self.image_dir = image_dir
#         self.shots_dir = shots_dir
#         self.transform = transform
#         self.image_pairs = []
#         self.labels = []
#         self._prepare_data()
#
#     def _prepare_data(self):
#         shots_files = os.listdir(self.shots_dir)
#         image_files = os.listdir(self.image_dir)
#         print(f"Number of shots: {len(shots_files)}")
#         print(f"Number of images in anonymized dataset: {len(image_files)}")
#         for shot in shots_files:
#             for img in image_files:
#                 shot_path = os.path.join(self.shots_dir, shot)
#                 img_path = os.path.join(self.image_dir, img)
#                 # Example condition for labeling, modify as needed
#                 label = 1 if shot.split('_')[0] == img.split('_')[0] else 0
#                 self.image_pairs.append((shot_path, img_path))
#                 self.labels.append(label)
#
#
#
#         print(f"Total image pairs created: {len(self.image_pairs)}")
#
#     def __len__(self):
#         return len(self.image_pairs)
#
#     def __getitem__(self, idx):
#         image1_path, image2_path = self.image_pairs[idx]
#         image1 = cv2.imread(image1_path)
#         image2 = cv2.imread(image2_path)
#         image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
#         image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)
#
#         if self.transform:
#             image1 = self.transform(image1)
#             image2 = self.transform(image2)
#
#         label = torch.tensor(self.labels[idx], dtype=torch.float32)
#         return image1, image2, label
#
#
#
# # Function to compute the Euclidean distance
# def euclidean_distance(a, b):
#     return F.pairwise_distance(a, b)
#
# # Training function
# def train(model, dataloader, criterion, optimizer, device):
#     model.train()
#     running_loss = 0.0
#     for image1, image2, label in dataloader:
#         image1, image2, label = image1.to(device), image2.to(device), label.to(device)
#         optimizer.zero_grad()
#         output1, output2 = model(image1, image2)
#         loss = criterion(euclidean_distance(output1, output2), label)
#         loss.backward()
#         optimizer.step()
#         running_loss += loss.item()
#     return running_loss / len(dataloader)
#
# # Evaluation function
# def evaluate(model, dataloader, threshold, device):
#     model.eval()
#     correct = 0
#     total = 0
#     with torch.no_grad():
#         for image1, image2, label in dataloader:
#             image1, image2, label = image1.to(device), image2.to(device), label.to(device)
#             output1, output2 = model(image1, image2)
#             distance = euclidean_distance(output1, output2)
#             predictions = (distance < threshold).float()
#             correct += (predictions == label).sum().item()
#             total += label.size(0)
#     return correct / total
#
# # Function to classify similarity of shots with anonymized dataset
# def classify_similarity(model, shots_dir, image_dir, threshold, device):
#     model.eval()
#     transform = transforms.Compose([
#         transforms.ToPILImage(),
#         transforms.Resize((224, 224)),
#         transforms.ToTensor(),
#
#     ])
#
#     shots_files = os.listdir(shots_dir)
#     image_files = os.listdir(image_dir)
#     results = []
#
#     with torch.no_grad():
#         for shot in shots_files:
#             shot_path = os.path.join(shots_dir, shot)
#             shot_image = cv2.imread(shot_path)
#             shot_image = cv2.cvtColor(shot_image, cv2.COLOR_BGR2RGB)
#             shot_image = transform(shot_image).unsqueeze(0).to(device)
#
#             for img in image_files:
#                 img_path = os.path.join(image_dir, img)
#                 img_image = cv2.imread(img_path)
#                 img_image = cv2.cvtColor(img_image, cv2.COLOR_BGR2RGB)
#                 img_image = transform(img_image).unsqueeze(0).to(device)
#
#                 output1, output2 = model(shot_image, img_image)
#                 distance = euclidean_distance(output1, output2).item()
#                 if distance < threshold:
#                     results.append((shot, img, distance))
#                     print(f"Shot: {shot}, Image: {img}, Distance: {distance}, Similar: True")
#                 else:
#                     print(f"Shot: {shot}, Image: {img}, Distance: {distance}, Similar: False")
#
#     return results
#
# # Main function
# def main(image_dir, shots_dir, batch_size=16, num_epochs=10, learning_rate=0.001, threshold=0.5):
#     device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#     dataset = ImagePairDataset(image_dir, shots_dir, transform=transform)
#
#     if len(dataset) == 0:
#         print("No image pairs found. Please check the dataset paths and image files.")
#         return
#
#     train_size = int(0.8 * len(dataset))
#     test_size = len(dataset) - train_size
#
#     if train_size == 0 or test_size == 0:
#         print(f"Train size: {train_size}, Test size: {test_size}. Not enough data to split.")
#         return
#
#     train_dataset, test_dataset = random_split(dataset, [train_size, test_size])
#     train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
#     test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
#
#     model = SiameseNetwork().to(device)
#     criterion = nn.BCEWithLogitsLoss()
#     optimizer = torch.optim.Adam(model.resnet.fc.parameters(), lr=learning_rate)
#
#     for epoch in range(num_epochs):
#         train_loss = train(model, train_loader, criterion, optimizer, device)
#         test_accuracy = evaluate(model, test_loader, threshold, device)
#         print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {train_loss:.4f}, Accuracy: {test_accuracy:.4f}")
#
#     print("Training complete")
#
#     # Final test evaluation
#     final_test_accuracy = evaluate(model, test_loader, threshold, device)
#     print(f"Final Test Accuracy: {final_test_accuracy:.4f}")
#
#     # Classify similarity
#     classify_similarity(model, shots_dir, image_dir, threshold, device)
#
# # Example usage
# image_dir = '/content/drive/MyDrive/urv/face_recognition/train/Aamir Khan'
# shots_dir = '/content/drive/MyDrive/urv/face_recognition/train/Aamir Khan'
# main(image_dir, shots_dir)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import models, transforms
import cv2
import os

# Define the image transformations
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# Define the function to get all files from directories and subdirectories
def get_all_files(dir_path):
    all_files = []
    for root, _, files in os.walk(dir_path):
        for file in files:
            if file.endswith(('jpg', 'jpeg', 'png')):
                all_files.append(os.path.join(root, file))
    return all_files

# Define the Siamese Network
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        self.resnet = models.resnet18(weights='IMAGENET1K_V1')

        # Freeze all layers except the classifier
        for param in self.resnet.parameters():
            param.requires_grad = False

        # Modify the fully connected layer
        self.resnet.fc = nn.Linear(self.resnet.fc.in_features, 512)

    def forward_one(self, x):
        x = self.resnet(x)
        return x

    def forward(self, input1, input2):
        output1 = self.forward_one(input1)
        output2 = self.forward_one(input2)
        return output1, output2

# Define the dataset for image pairs
class ImagePairDataset(Dataset):
    def __init__(self, image_dir, shots_dir, transform=None):
        self.image_dir = image_dir
        self.shots_dir = shots_dir
        self.transform = transform
        self.image_pairs = []
        self.labels = []
        self._prepare_data()

    def _prepare_data(self):
        shots_files = get_all_files(self.shots_dir)
        image_files = get_all_files(self.image_dir)

        print(f"Number of shots: {len(shots_files)}")
        print(f"Number of images in anonymized dataset: {len(image_files)}")

        for shot_path in shots_files:
            for img_path in image_files:
                shot_id = os.path.basename(os.path.dirname(shot_path))
                img_id = os.path.basename(os.path.dirname(img_path))

                # Label 1 if they are from the same person, otherwise 0
                label = 1 if shot_id == img_id else 0

                self.image_pairs.append((shot_path, img_path))
                self.labels.append(label)

        print(f"Total image pairs created: {len(self.image_pairs)}")

    def __len__(self):
        return len(self.image_pairs)

    def __getitem__(self, idx):
        image1_path, image2_path = self.image_pairs[idx]
        image1 = cv2.imread(image1_path)
        image2 = cv2.imread(image2_path)
        image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
        image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

        if self.transform:
            image1 = self.transform(image1)
            image2 = self.transform(image2)

        label = torch.tensor(self.labels[idx], dtype=torch.float32)
        return image1, image2, label

# Function to compute the Euclidean distance
def euclidean_distance(a, b):
    return F.pairwise_distance(a, b)

# Training function
def train(model, dataloader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    for image1, image2, label in dataloader:
        image1, image2, label = image1.to(device), image2.to(device), label.to(device)
        optimizer.zero_grad()
        output1, output2 = model(image1, image2)
        loss = criterion(euclidean_distance(output1, output2), label)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    return running_loss / len(dataloader)

# Evaluation function
def evaluate(model, dataloader, threshold, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for image1, image2, label in dataloader:
            image1, image2, label = image1.to(device), image2.to(device), label.to(device)
            output1, output2 = model(image1, image2)
            distance = euclidean_distance(output1, output2)
            predictions = (distance < threshold).float()
            correct += (predictions == label).sum().item()
            total += label.size(0)
    return correct / total

# Function to classify similarity of shots with anonymized dataset
def classify_similarity(model, shots_dir, image_dir, threshold, device):
    model.eval()
    transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
    ])

    shots_files = get_all_files(shots_dir)
    image_files = get_all_files(image_dir)
    results = []

    with torch.no_grad():
        for shot_path in shots_files:
            shot_name = os.path.basename(shot_path)
            shot_image = cv2.imread(shot_path)
            shot_image = cv2.cvtColor(shot_image, cv2.COLOR_BGR2RGB)
            shot_image = transform(shot_image).unsqueeze(0).to(device)

            for img_path in image_files:
                img_name = os.path.basename(img_path)
                img_image = cv2.imread(img_path)
                img_image = cv2.cvtColor(img_image, cv2.COLOR_BGR2RGB)
                img_image = transform(img_image).unsqueeze(0).to(device)
                # label = 1 if shot_image == image_files else 0
                label = 1 if shot_name == img_name else 0
                output1, output2 = model(shot_image, img_image)
                distance = euclidean_distance(output1, output2).item()
                similar = distance < threshold
                results.append((shot_name, img_name, distance, similar))

                # Print shot name, image name, and similarity status
                if similar:
                    print(f"Shot: {shot_name}, Image: {img_name}, Distance: {distance:.4f}, Similar: True, label: {label}")
                else:
                    print(f"Shot: {shot_name}, Image: {img_name}, Distance: {distance:.4f}, Similar: False, label: {label}")

    return results

# Main function
def main(image_dir, shots_dir, batch_size=16, num_epochs=150, learning_rate=0.001, threshold=6.0):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    dataset = ImagePairDataset(image_dir, shots_dir, transform=transform)

    if len(dataset) == 0:
        print("No image pairs found. Please check the dataset paths and image files.")
        return

    train_size = int(0.8 * len(dataset))
    test_size = len(dataset) - train_size

    if train_size == 0 or test_size == 0:
        print(f"Train size: {train_size}, Test size: {test_size}. Not enough data to split.")
        return

    train_dataset, test_dataset = random_split(dataset, [train_size, test_size])
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    model = SiameseNetwork().to(device)
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.Adam(model.resnet.fc.parameters(), lr=learning_rate)

    for epoch in range(num_epochs):
        train_loss = train(model, train_loader, criterion, optimizer, device)
        test_accuracy = evaluate(model, test_loader, threshold, device)
        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {train_loss:.4f}, Accuracy: {test_accuracy:.4f}")

    print("Training complete")
    torch.save(model.state_dict(), "/content/drive/MyDrive/urv/distance_model.pt")
    # Final test evaluation
    final_test_accuracy = evaluate(model, test_loader, threshold, device)
    print(f"Final Test Accuracy: {final_test_accuracy:.4f}")

    # Classify similarity
    classify_similarity(model, shots_dir, image_dir, threshold, device)

# Example usage
image_dir = '/content/drive/MyDrive/urv/Images_For_The_Person_i_Want_To_Identify_In_Anonymized_Dataset_with_noise'
shots_dir = '/content/drive/MyDrive/urv/Images_For_The_Person_i_Want_To_Identify_In_Anonymized_Dataset_without_noise'
main(image_dir, shots_dir)
# Out:
# Number of shots: 26
# Number of images in anonymized dataset: 26
# Total image pairs created: 676
# Epoch [1/150], Loss: 2.8778, Accuracy: 0.3603
# Epoch [2/150], Loss: 1.7463, Accuracy: 0.3603
# Epoch [3/150], Loss: 1.5434, Accuracy: 0.3603
# Epoch [4/150], Loss: 1.4995, Accuracy: 0.3603
# Epoch [5/150], Loss: 1.4531, Accuracy: 0.3824
# Epoch [6/150], Loss: 1.4114, Accuracy: 0.3897
# Epoch [7/150], Loss: 1.3575, Accuracy: 0.4044
# Epoch [8/150], Loss: 1.2977, Accuracy: 0.4559
# Epoch [9/150], Loss: 1.2946, Accuracy: 0.4926
# Epoch [10/150], Loss: 1.2718, Accuracy: 0.5515
# Epoch [11/150], Loss: 1.2560, Accuracy: 0.5294
# Epoch [12/150], Loss: 1.2387, Accuracy: 0.6029
# Epoch [13/150], Loss: 1.1953, Accuracy: 0.6029
# Epoch [14/150], Loss: 1.2022, Accuracy: 0.6176
# Epoch [15/150], Loss: 1.2186, Accuracy: 0.6324
# Epoch [16/150], Loss: 1.2130, Accuracy: 0.6250
# Epoch [17/150], Loss: 1.1928, Accuracy: 0.6250
# Epoch [18/150], Loss: 1.1722, Accuracy: 0.6397
# Epoch [19/150], Loss: 1.1701, Accuracy: 0.6324
# Epoch [20/150], Loss: 1.1953, Accuracy: 0.6397
# Epoch [21/150], Loss: 1.1554, Accuracy: 0.6397
# Epoch [22/150], Loss: 1.1154, Accuracy: 0.6397
# Epoch [23/150], Loss: 1.1178, Accuracy: 0.6397
# Epoch [24/150], Loss: 1.0714, Accuracy: 0.6397
# Epoch [25/150], Loss: 1.1135, Accuracy: 0.6397
# Epoch [26/150], Loss: 1.0918, Accuracy: 0.6397
# Epoch [27/150], Loss: 1.0805, Accuracy: 0.6397
# Epoch [28/150], Loss: 1.1284, Accuracy: 0.6397
# Epoch [29/150], Loss: 1.0985, Accuracy: 0.6397
# Epoch [30/150], Loss: 1.1167, Accuracy: 0.6397
# Epoch [31/150], Loss: 1.0685, Accuracy: 0.6397
# Epoch [32/150], Loss: 1.1015, Accuracy: 0.6397
# Epoch [33/150], Loss: 1.0827, Accuracy: 0.6397
# Epoch [34/150], Loss: 1.0679, Accuracy: 0.6397
# Epoch [35/150], Loss: 1.0639, Accuracy: 0.6397
# Epoch [36/150], Loss: 1.0768, Accuracy: 0.6397
# Epoch [37/150], Loss: 1.0657, Accuracy: 0.6397
# Epoch [38/150], Loss: 1.0621, Accuracy: 0.6397
# Epoch [39/150], Loss: 1.0636, Accuracy: 0.6397
# Epoch [40/150], Loss: 1.1147, Accuracy: 0.6397
# Epoch [41/150], Loss: 1.0842, Accuracy: 0.6397
# Epoch [42/150], Loss: 1.0853, Accuracy: 0.6397
# Epoch [43/150], Loss: 1.0706, Accuracy: 0.6397
# Epoch [44/150], Loss: 1.0497, Accuracy: 0.6397
# Epoch [45/150], Loss: 1.0652, Accuracy: 0.6397
# Epoch [46/150], Loss: 1.0858, Accuracy: 0.6397
# Epoch [47/150], Loss: 1.0617, Accuracy: 0.6397
# Epoch [48/150], Loss: 1.0498, Accuracy: 0.6397
# Epoch [49/150], Loss: 1.0048, Accuracy: 0.6397
# Epoch [50/150], Loss: 1.0459, Accuracy: 0.6397
# Epoch [51/150], Loss: 1.0128, Accuracy: 0.6397
# Epoch [52/150], Loss: 1.0345, Accuracy: 0.6397
# Epoch [53/150], Loss: 1.0500, Accuracy: 0.6397
# Epoch [54/150], Loss: 1.0327, Accuracy: 0.6397
# Epoch [55/150], Loss: 1.0364, Accuracy: 0.6397
# Epoch [56/150], Loss: 0.9845, Accuracy: 0.6397
# Epoch [57/150], Loss: 1.0245, Accuracy: 0.6397
# Epoch [58/150], Loss: 1.0375, Accuracy: 0.6397
# Epoch [59/150], Loss: 1.0225, Accuracy: 0.6397
# Epoch [60/150], Loss: 1.0251, Accuracy: 0.6397
# Epoch [61/150], Loss: 1.0124, Accuracy: 0.6397
# Epoch [62/150], Loss: 0.9782, Accuracy: 0.6397
# Epoch [63/150], Loss: 1.0071, Accuracy: 0.6397
# Epoch [64/150], Loss: 1.0315, Accuracy: 0.6397
# Epoch [65/150], Loss: 1.0076, Accuracy: 0.6397
# Epoch [66/150], Loss: 1.0054, Accuracy: 0.6397
# Epoch [67/150], Loss: 0.9769, Accuracy: 0.6397
# Epoch [68/150], Loss: 1.0362, Accuracy: 0.6397
# Epoch [69/150], Loss: 0.9868, Accuracy: 0.6397
# Epoch [70/150], Loss: 0.9758, Accuracy: 0.6397
# Epoch [71/150], Loss: 0.9415, Accuracy: 0.6397
# Epoch [72/150], Loss: 0.9644, Accuracy: 0.6397
# Epoch [73/150], Loss: 0.9934, Accuracy: 0.6397
# Epoch [74/150], Loss: 0.9565, Accuracy: 0.6397
# Epoch [75/150], Loss: 0.9827, Accuracy: 0.6397
# Epoch [76/150], Loss: 1.0078, Accuracy: 0.6397
# Epoch [77/150], Loss: 0.9889, Accuracy: 0.6397
# Epoch [78/150], Loss: 0.9777, Accuracy: 0.6397
# Epoch [79/150], Loss: 0.9654, Accuracy: 0.6397
# Epoch [80/150], Loss: 0.9730, Accuracy: 0.6397
# Epoch [81/150], Loss: 0.9497, Accuracy: 0.6397
# Epoch [82/150], Loss: 0.9571, Accuracy: 0.6397
# Epoch [83/150], Loss: 0.9835, Accuracy: 0.6397
# Epoch [84/150], Loss: 1.0477, Accuracy: 0.6397
# Epoch [85/150], Loss: 1.0184, Accuracy: 0.6397
# Epoch [86/150], Loss: 0.9498, Accuracy: 0.6397
# Epoch [87/150], Loss: 0.9604, Accuracy: 0.6397
# Epoch [88/150], Loss: 0.9581, Accuracy: 0.6397
# Epoch [89/150], Loss: 0.9979, Accuracy: 0.6397
# Epoch [90/150], Loss: 0.9962, Accuracy: 0.6397
# Epoch [91/150], Loss: 1.0268, Accuracy: 0.6397
# Epoch [92/150], Loss: 1.0076, Accuracy: 0.6397
# Epoch [93/150], Loss: 0.9899, Accuracy: 0.6397
# Epoch [94/150], Loss: 0.9939, Accuracy: 0.6397
# Epoch [95/150], Loss: 1.0226, Accuracy: 0.6324
# Epoch [96/150], Loss: 0.9809, Accuracy: 0.6397
# Epoch [97/150], Loss: 0.9370, Accuracy: 0.6397
# Epoch [98/150], Loss: 0.9607, Accuracy: 0.6397
# Epoch [99/150], Loss: 0.9833, Accuracy: 0.6397
# Epoch [100/150], Loss: 0.9665, Accuracy: 0.6324
# Epoch [101/150], Loss: 0.9768, Accuracy: 0.6397
# Epoch [102/150], Loss: 0.9842, Accuracy: 0.6397
# Epoch [103/150], Loss: 0.9647, Accuracy: 0.6397
# Epoch [104/150], Loss: 0.9559, Accuracy: 0.6324
# Epoch [105/150], Loss: 0.9597, Accuracy: 0.6397
# Epoch [106/150], Loss: 0.9452, Accuracy: 0.6324
# Epoch [107/150], Loss: 0.9389, Accuracy: 0.6397
# Epoch [108/150], Loss: 0.9852, Accuracy: 0.6397
# Epoch [109/150], Loss: 0.9480, Accuracy: 0.6397
# Epoch [110/150], Loss: 0.9735, Accuracy: 0.6397
# Epoch [111/150], Loss: 0.9623, Accuracy: 0.6397
# Epoch [112/150], Loss: 0.9911, Accuracy: 0.6324
# Epoch [113/150], Loss: 0.9794, Accuracy: 0.6324
# Epoch [114/150], Loss: 0.9953, Accuracy: 0.6397
# Epoch [115/150], Loss: 0.9745, Accuracy: 0.6324
# Epoch [116/150], Loss: 1.0136, Accuracy: 0.6397
# Epoch [117/150], Loss: 0.9317, Accuracy: 0.6397
# Epoch [118/150], Loss: 1.0008, Accuracy: 0.6397
# Epoch [119/150], Loss: 0.9507, Accuracy: 0.6103
# Epoch [120/150], Loss: 0.9536, Accuracy: 0.6029
# Epoch [121/150], Loss: 0.9844, Accuracy: 0.6397
# Epoch [122/150], Loss: 0.9750, Accuracy: 0.6397
# Epoch [123/150], Loss: 0.9429, Accuracy: 0.6176
# Epoch [124/150], Loss: 0.9565, Accuracy: 0.6250
# Epoch [125/150], Loss: 0.9246, Accuracy: 0.6397
# Epoch [126/150], Loss: 0.9292, Accuracy: 0.6324
# Epoch [127/150], Loss: 0.9458, Accuracy: 0.6397
# Epoch [128/150], Loss: 0.9577, Accuracy: 0.6397
# Epoch [129/150], Loss: 0.9205, Accuracy: 0.6397
# Epoch [130/150], Loss: 0.9050, Accuracy: 0.6250
# Epoch [131/150], Loss: 0.9074, Accuracy: 0.6397
# Epoch [132/150], Loss: 0.9385, Accuracy: 0.6250
# Epoch [133/150], Loss: 0.9237, Accuracy: 0.6324
# Epoch [134/150], Loss: 0.9438, Accuracy: 0.6397
# Epoch [135/150], Loss: 0.9571, Accuracy: 0.6324
# Epoch [136/150], Loss: 0.9341, Accuracy: 0.6397
# Epoch [137/150], Loss: 0.9744, Accuracy: 0.6324
# Epoch [138/150], Loss: 1.0305, Accuracy: 0.6324
# Epoch [139/150], Loss: 0.9520, Accuracy: 0.6397
# Epoch [140/150], Loss: 0.9592, Accuracy: 0.6250
# Epoch [141/150], Loss: 0.9596, Accuracy: 0.6250
# Epoch [142/150], Loss: 0.9347, Accuracy: 0.6324
# Epoch [143/150], Loss: 0.9248, Accuracy: 0.6324
# Epoch [144/150], Loss: 0.9442, Accuracy: 0.6176
# Epoch [145/150], Loss: 0.9779, Accuracy: 0.6250
# Epoch [146/150], Loss: 0.9766, Accuracy: 0.6029
# Epoch [147/150], Loss: 0.9315, Accuracy: 0.6250
# Epoch [148/150], Loss: 0.9760, Accuracy: 0.6324
# Epoch [149/150], Loss: 0.9265, Accuracy: 0.6324
# Epoch [150/150], Loss: 0.9495, Accuracy: 0.6176
# Training complete
# Final Test Accuracy: 0.6176
# Shot: 5.jpg, Image: 3.jpg, Distance: 2.7759, Similar: True, label: 0
# Shot: 5.jpg, Image: 0.jpg, Distance: 2.4789, Similar: True, label: 0
# Shot: 5.jpg, Image: 1.jpg, Distance: 2.5987, Similar: True, label: 0
# Shot: 5.jpg, Image: 2.jpg, Distance: 2.6475, Similar: True, label: 0
# Shot: 5.jpg, Image: 5.jpg, Distance: 2.3003, Similar: True, label: 1
# Shot: 5.jpg, Image: 4.jpg, Distance: 2.1856, Similar: True, label: 0
# Shot: 5.jpg, Image: 6.jpg, Distance: 1.8769, Similar: True, label: 0
# Shot: 5.jpg, Image: 2.jpg, Distance: 3.1760, Similar: True, label: 0
# Shot: 5.jpg, Image: 3.jpg, Distance: 2.6510, Similar: True, label: 0
# Shot: 5.jpg, Image: 0.jpg, Distance: 3.4691, Similar: True, label: 0
# Shot: 5.jpg, Image: 4.jpg, Distance: 3.2515, Similar: True, label: 0
# Shot: 5.jpg, Image: 1.jpg, Distance: 2.4570, Similar: True, label: 0
# Shot: 5.jpg, Image: 5.jpg, Distance: 3.3013, Similar: True, label: 1
# Shot: 5.jpg, Image: 11.jpg, Distance: 2.3436, Similar: True, label: 0
# Shot: 5.jpg, Image: 8.jpg, Distance: 3.2161, Similar: True, label: 0
# Shot: 5.jpg, Image: 12.jpg, Distance: 2.8804, Similar: True, label: 0
# Shot: 5.jpg, Image: 6.jpg, Distance: 3.1687, Similar: True, label: 0
# Shot: 5.jpg, Image: 9.jpg, Distance: 4.8937, Similar: True, label: 0
# Shot: 5.jpg, Image: 10.jpg, Distance: 2.2662, Similar: True, label: 0
# Shot: 5.jpg, Image: 14.jpg, Distance: 2.4999, Similar: True, label: 0
# Shot: 5.jpg, Image: 7.jpg, Distance: 3.6492, Similar: True, label: 0
# Shot: 5.jpg, Image: 13.jpg, Distance: 3.6250, Similar: True, label: 0
# Shot: 5.jpg, Image: 15.jpg, Distance: 3.5176, Similar: True, label: 0
# Shot: 5.jpg, Image: 18.jpg, Distance: 2.5982, Similar: True, label: 0
# Shot: 5.jpg, Image: 17.jpg, Distance: 3.0830, Similar: True, label: 0
# Shot: 5.jpg, Image: 16.jpg, Distance: 2.8299, Similar: True, label: 0
# Shot: 4.jpg, Image: 3.jpg, Distance: 2.6100, Similar: True, label: 0
# Shot: 4.jpg, Image: 0.jpg, Distance: 2.0696, Similar: True, label: 0
# Shot: 4.jpg, Image: 1.jpg, Distance: 2.1940, Similar: True, label: 0
# Shot: 4.jpg, Image: 2.jpg, Distance: 2.4701, Similar: True, label: 0
# Shot: 4.jpg, Image: 5.jpg, Distance: 2.5498, Similar: True, label: 0
# Shot: 4.jpg, Image: 4.jpg, Distance: 2.2970, Similar: True, label: 1
# Shot: 4.jpg, Image: 6.jpg, Distance: 1.7101, Similar: True, label: 0
# Shot: 4.jpg, Image: 2.jpg, Distance: 3.3219, Similar: True, label: 0
# Shot: 4.jpg, Image: 3.jpg, Distance: 2.6645, Similar: True, label: 0
# Shot: 4.jpg, Image: 0.jpg, Distance: 3.4971, Similar: True, label: 0
# Shot: 4.jpg, Image: 4.jpg, Distance: 3.0852, Similar: True, label: 1
# Shot: 4.jpg, Image: 1.jpg, Distance: 1.9843, Similar: True, label: 0
# Shot: 4.jpg, Image: 5.jpg, Distance: 3.2648, Similar: True, label: 0
# Shot: 4.jpg, Image: 11.jpg, Distance: 2.4634, Similar: True, label: 0
# Shot: 4.jpg, Image: 8.jpg, Distance: 3.4251, Similar: True, label: 0
# Shot: 4.jpg, Image: 12.jpg, Distance: 3.0695, Similar: True, label: 0
# Shot: 4.jpg, Image: 6.jpg, Distance: 3.0876, Similar: True, label: 0
# Shot: 4.jpg, Image: 9.jpg, Distance: 5.0225, Similar: True, label: 0
# Shot: 4.jpg, Image: 10.jpg, Distance: 2.0584, Similar: True, label: 0
# Shot: 4.jpg, Image: 14.jpg, Distance: 2.1826, Similar: True, label: 0
# Shot: 4.jpg, Image: 7.jpg, Distance: 3.7341, Similar: True, label: 0
# Shot: 4.jpg, Image: 13.jpg, Distance: 3.5067, Similar: True, label: 0
# Shot: 4.jpg, Image: 15.jpg, Distance: 3.5318, Similar: True, label: 0
# Shot: 4.jpg, Image: 18.jpg, Distance: 2.4602, Similar: True, label: 0
# Shot: 4.jpg, Image: 17.jpg, Distance: 3.1120, Similar: True, label: 0
# Shot: 4.jpg, Image: 16.jpg, Distance: 2.8133, Similar: True, label: 0
# Shot: 3.jpg, Image: 3.jpg, Distance: 3.2582, Similar: True, label: 1
# Shot: 3.jpg, Image: 0.jpg, Distance: 2.8862, Similar: True, label: 0
# Shot: 3.jpg, Image: 1.jpg, Distance: 3.1159, Similar: True, label: 0
# Shot: 3.jpg, Image: 2.jpg, Distance: 3.1463, Similar: True, label: 0
# Shot: 3.jpg, Image: 5.jpg, Distance: 2.5030, Similar: True, label: 0
# Shot: 3.jpg, Image: 4.jpg, Distance: 2.7904, Similar: True, label: 0
# Shot: 3.jpg, Image: 6.jpg, Distance: 2.1472, Similar: True, label: 0
# Shot: 3.jpg, Image: 2.jpg, Distance: 2.7375, Similar: True, label: 0
# Shot: 3.jpg, Image: 3.jpg, Distance: 2.4690, Similar: True, label: 1
# Shot: 3.jpg, Image: 0.jpg, Distance: 2.8367, Similar: True, label: 0
# Shot: 3.jpg, Image: 4.jpg, Distance: 2.7528, Similar: True, label: 0
# Shot: 3.jpg, Image: 1.jpg, Distance: 2.1730, Similar: True, label: 0
# Shot: 3.jpg, Image: 5.jpg, Distance: 2.8618, Similar: True, label: 0
# Shot: 3.jpg, Image: 11.jpg, Distance: 2.2233, Similar: True, label: 0
# Shot: 3.jpg, Image: 8.jpg, Distance: 2.8136, Similar: True, label: 0
# Shot: 3.jpg, Image: 12.jpg, Distance: 3.0959, Similar: True, label: 0
# Shot: 3.jpg, Image: 6.jpg, Distance: 2.7490, Similar: True, label: 0
# Shot: 3.jpg, Image: 9.jpg, Distance: 4.1444, Similar: True, label: 0
# Shot: 3.jpg, Image: 10.jpg, Distance: 2.3580, Similar: True, label: 0
# Shot: 3.jpg, Image: 14.jpg, Distance: 2.6016, Similar: True, label: 0
# Shot: 3.jpg, Image: 7.jpg, Distance: 3.0765, Similar: True, label: 0
# Shot: 3.jpg, Image: 13.jpg, Distance: 3.0618, Similar: True, label: 0
# Shot: 3.jpg, Image: 15.jpg, Distance: 2.8123, Similar: True, label: 0
# Shot: 3.jpg, Image: 18.jpg, Distance: 2.1917, Similar: True, label: 0
# Shot: 3.jpg, Image: 17.jpg, Distance: 2.5802, Similar: True, label: 0
# Shot: 3.jpg, Image: 16.jpg, Distance: 2.7162, Similar: True, label: 0
# Shot: 0.jpg, Image: 3.jpg, Distance: 2.6880, Similar: True, label: 0
# Shot: 0.jpg, Image: 0.jpg, Distance: 2.6988, Similar: True, label: 1
# Shot: 0.jpg, Image: 1.jpg, Distance: 2.8342, Similar: True, label: 0
# Shot: 0.jpg, Image: 2.jpg, Distance: 2.8956, Similar: True, label: 0
# Shot: 0.jpg, Image: 5.jpg, Distance: 2.0587, Similar: True, label: 0
# Shot: 0.jpg, Image: 4.jpg, Distance: 1.9429, Similar: True, label: 0
# Shot: 0.jpg, Image: 6.jpg, Distance: 2.1528, Similar: True, label: 0
# Shot: 0.jpg, Image: 2.jpg, Distance: 2.8661, Similar: True, label: 0
# Shot: 0.jpg, Image: 3.jpg, Distance: 2.7100, Similar: True, label: 0
# Shot: 0.jpg, Image: 0.jpg, Distance: 3.2561, Similar: True, label: 1
# Shot: 0.jpg, Image: 4.jpg, Distance: 3.2160, Similar: True, label: 0
# Shot: 0.jpg, Image: 1.jpg, Distance: 2.6725, Similar: True, label: 0
# Shot: 0.jpg, Image: 5.jpg, Distance: 3.0854, Similar: True, label: 0
# Shot: 0.jpg, Image: 11.jpg, Distance: 2.0304, Similar: True, label: 0
# Shot: 0.jpg, Image: 8.jpg, Distance: 2.7613, Similar: True, label: 0
# Shot: 0.jpg, Image: 12.jpg, Distance: 2.5755, Similar: True, label: 0
# Shot: 0.jpg, Image: 6.jpg, Distance: 2.9857, Similar: True, label: 0
# Shot: 0.jpg, Image: 9.jpg, Distance: 4.5921, Similar: True, label: 0
# Shot: 0.jpg, Image: 10.jpg, Distance: 2.9238, Similar: True, label: 0
# Shot: 0.jpg, Image: 14.jpg, Distance: 2.7288, Similar: True, label: 0
# Shot: 0.jpg, Image: 7.jpg, Distance: 3.4644, Similar: True, label: 0
# Shot: 0.jpg, Image: 13.jpg, Distance: 3.9378, Similar: True, label: 0
# Shot: 0.jpg, Image: 15.jpg, Distance: 3.2915, Similar: True, label: 0
# Shot: 0.jpg, Image: 18.jpg, Distance: 2.1723, Similar: True, label: 0
# Shot: 0.jpg, Image: 17.jpg, Distance: 2.5450, Similar: True, label: 0
# Shot: 0.jpg, Image: 16.jpg, Distance: 2.4236, Similar: True, label: 0
# Shot: 2.jpg, Image: 3.jpg, Distance: 2.7814, Similar: True, label: 0
# Shot: 2.jpg, Image: 0.jpg, Distance: 2.6384, Similar: True, label: 0
# Shot: 2.jpg, Image: 1.jpg, Distance: 2.2660, Similar: True, label: 0
# Shot: 2.jpg, Image: 2.jpg, Distance: 2.1786, Similar: True, label: 1
# Shot: 2.jpg, Image: 5.jpg, Distance: 3.6474, Similar: True, label: 0
# Shot: 2.jpg, Image: 4.jpg, Distance: 2.7246, Similar: True, label: 0
# Shot: 2.jpg, Image: 6.jpg, Distance: 2.9574, Similar: True, label: 0
# Shot: 2.jpg, Image: 2.jpg, Distance: 4.8516, Similar: True, label: 1
# Shot: 2.jpg, Image: 3.jpg, Distance: 4.1831, Similar: True, label: 0
# Shot: 2.jpg, Image: 0.jpg, Distance: 5.1134, Similar: True, label: 0
# Shot: 2.jpg, Image: 4.jpg, Distance: 4.7111, Similar: True, label: 0
# Shot: 2.jpg, Image: 1.jpg, Distance: 3.1172, Similar: True, label: 0
# Shot: 2.jpg, Image: 5.jpg, Distance: 4.7937, Similar: True, label: 0
# Shot: 2.jpg, Image: 11.jpg, Distance: 3.7072, Similar: True, label: 0
# Shot: 2.jpg, Image: 8.jpg, Distance: 4.7010, Similar: True, label: 0
# Shot: 2.jpg, Image: 12.jpg, Distance: 4.3655, Similar: True, label: 0
# Shot: 2.jpg, Image: 6.jpg, Distance: 4.6010, Similar: True, label: 0
# Shot: 2.jpg, Image: 9.jpg, Distance: 6.6723, Similar: False, label: 0
# Shot: 2.jpg, Image: 10.jpg, Distance: 3.0348, Similar: True, label: 0
# Shot: 2.jpg, Image: 14.jpg, Distance: 3.1921, Similar: True, label: 0
# Shot: 2.jpg, Image: 7.jpg, Distance: 5.3561, Similar: True, label: 0
# Shot: 2.jpg, Image: 13.jpg, Distance: 4.9411, Similar: True, label: 0
# Shot: 2.jpg, Image: 15.jpg, Distance: 5.1755, Similar: True, label: 0
# Shot: 2.jpg, Image: 18.jpg, Distance: 3.8928, Similar: True, label: 0
# Shot: 2.jpg, Image: 17.jpg, Distance: 4.4020, Similar: True, label: 0
# Shot: 2.jpg, Image: 16.jpg, Distance: 4.1379, Similar: True, label: 0
# Shot: 6.jpg, Image: 3.jpg, Distance: 3.9087, Similar: True, label: 0
# Shot: 6.jpg, Image: 0.jpg, Distance: 3.4227, Similar: True, label: 0
# Shot: 6.jpg, Image: 1.jpg, Distance: 3.8769, Similar: True, label: 0
# Shot: 6.jpg, Image: 2.jpg, Distance: 3.6566, Similar: True, label: 0
# Shot: 6.jpg, Image: 5.jpg, Distance: 2.4986, Similar: True, label: 0
# Shot: 6.jpg, Image: 4.jpg, Distance: 3.1843, Similar: True, label: 0
# Shot: 6.jpg, Image: 6.jpg, Distance: 2.6359, Similar: True, label: 1
# Shot: 6.jpg, Image: 2.jpg, Distance: 2.5940, Similar: True, label: 0
# Shot: 6.jpg, Image: 3.jpg, Distance: 2.7215, Similar: True, label: 0
# Shot: 6.jpg, Image: 0.jpg, Distance: 2.5513, Similar: True, label: 0
# Shot: 6.jpg, Image: 4.jpg, Distance: 2.6034, Similar: True, label: 0
# Shot: 6.jpg, Image: 1.jpg, Distance: 2.5709, Similar: True, label: 0
# Shot: 6.jpg, Image: 5.jpg, Distance: 2.5265, Similar: True, label: 0
# Shot: 6.jpg, Image: 11.jpg, Distance: 2.1895, Similar: True, label: 0
# Shot: 6.jpg, Image: 8.jpg, Distance: 2.5046, Similar: True, label: 0
# Shot: 6.jpg, Image: 12.jpg, Distance: 3.0873, Similar: True, label: 0
# Shot: 6.jpg, Image: 6.jpg, Distance: 2.6712, Similar: True, label: 1
# Shot: 6.jpg, Image: 9.jpg, Distance: 3.6133, Similar: True, label: 0
# Shot: 6.jpg, Image: 10.jpg, Distance: 2.7637, Similar: True, label: 0
# Shot: 6.jpg, Image: 14.jpg, Distance: 2.6154, Similar: True, label: 0
# Shot: 6.jpg, Image: 7.jpg, Distance: 2.6288, Similar: True, label: 0
# Shot: 6.jpg, Image: 13.jpg, Distance: 3.1487, Similar: True, label: 0
# Shot: 6.jpg, Image: 15.jpg, Distance: 2.5115, Similar: True, label: 0
# Shot: 6.jpg, Image: 18.jpg, Distance: 2.3873, Similar: True, label: 0
# Shot: 6.jpg, Image: 17.jpg, Distance: 2.5272, Similar: True, label: 0
# Shot: 6.jpg, Image: 16.jpg, Distance: 2.8957, Similar: True, label: 0
# Shot: 1.jpg, Image: 3.jpg, Distance: 2.3187, Similar: True, label: 0
# Shot: 1.jpg, Image: 0.jpg, Distance: 1.8887, Similar: True, label: 0
# Shot: 1.jpg, Image: 1.jpg, Distance: 1.9712, Similar: True, label: 1
# Shot: 1.jpg, Image: 2.jpg, Distance: 2.3963, Similar: True, label: 0
# Shot: 1.jpg, Image: 5.jpg, Distance: 2.8111, Similar: True, label: 0
# Shot: 1.jpg, Image: 4.jpg, Distance: 2.0876, Similar: True, label: 0
# Shot: 1.jpg, Image: 6.jpg, Distance: 1.7521, Similar: True, label: 0
# Shot: 1.jpg, Image: 2.jpg, Distance: 3.6621, Similar: True, label: 0
# Shot: 1.jpg, Image: 3.jpg, Distance: 2.7771, Similar: True, label: 0
# Shot: 1.jpg, Image: 0.jpg, Distance: 3.9013, Similar: True, label: 0
# Shot: 1.jpg, Image: 4.jpg, Distance: 3.5276, Similar: True, label: 0
# Shot: 1.jpg, Image: 1.jpg, Distance: 2.1180, Similar: True, label: 1
# Shot: 1.jpg, Image: 5.jpg, Distance: 3.6405, Similar: True, label: 0
# Shot: 1.jpg, Image: 11.jpg, Distance: 2.8751, Similar: True, label: 0
# Shot: 1.jpg, Image: 8.jpg, Distance: 3.7513, Similar: True, label: 0
# Shot: 1.jpg, Image: 12.jpg, Distance: 3.2175, Similar: True, label: 0
# Shot: 1.jpg, Image: 6.jpg, Distance: 3.5961, Similar: True, label: 0
# Shot: 1.jpg, Image: 9.jpg, Distance: 5.4890, Similar: True, label: 0
# Shot: 1.jpg, Image: 10.jpg, Distance: 2.3560, Similar: True, label: 0
# Shot: 1.jpg, Image: 14.jpg, Distance: 2.4140, Similar: True, label: 0
# Shot: 1.jpg, Image: 7.jpg, Distance: 4.1242, Similar: True, label: 0
# Shot: 1.jpg, Image: 13.jpg, Distance: 3.8899, Similar: True, label: 0
# Shot: 1.jpg, Image: 15.jpg, Distance: 4.0560, Similar: True, label: 0
# Shot: 1.jpg, Image: 18.jpg, Distance: 2.9033, Similar: True, label: 0
# Shot: 1.jpg, Image: 17.jpg, Distance: 3.3607, Similar: True, label: 0
# Shot: 1.jpg, Image: 16.jpg, Distance: 3.0984, Similar: True, label: 0
# Shot: 12.jpg, Image: 3.jpg, Distance: 3.4129, Similar: True, label: 0
# Shot: 12.jpg, Image: 0.jpg, Distance: 3.0463, Similar: True, label: 0
# Shot: 12.jpg, Image: 1.jpg, Distance: 3.4912, Similar: True, label: 0
# Shot: 12.jpg, Image: 2.jpg, Distance: 3.1585, Similar: True, label: 0
# Shot: 12.jpg, Image: 5.jpg, Distance: 2.6812, Similar: True, label: 0
# Shot: 12.jpg, Image: 4.jpg, Distance: 2.9076, Similar: True, label: 0
# Shot: 12.jpg, Image: 6.jpg, Distance: 2.4373, Similar: True, label: 0
# Shot: 12.jpg, Image: 2.jpg, Distance: 1.9885, Similar: True, label: 0
# Shot: 12.jpg, Image: 3.jpg, Distance: 2.1346, Similar: True, label: 0
# Shot: 12.jpg, Image: 0.jpg, Distance: 2.0239, Similar: True, label: 0
# Shot: 12.jpg, Image: 4.jpg, Distance: 2.0373, Similar: True, label: 0
# Shot: 12.jpg, Image: 1.jpg, Distance: 2.3348, Similar: True, label: 0
# Shot: 12.jpg, Image: 5.jpg, Distance: 2.0074, Similar: True, label: 0
# Shot: 12.jpg, Image: 11.jpg, Distance: 2.3591, Similar: True, label: 0
# Shot: 12.jpg, Image: 8.jpg, Distance: 2.3497, Similar: True, label: 0
# Shot: 12.jpg, Image: 12.jpg, Distance: 2.5934, Similar: True, label: 1
# Shot: 12.jpg, Image: 6.jpg, Distance: 1.8036, Similar: True, label: 0
# Shot: 12.jpg, Image: 9.jpg, Distance: 3.5455, Similar: True, label: 0
# Shot: 12.jpg, Image: 10.jpg, Distance: 2.6103, Similar: True, label: 0
# Shot: 12.jpg, Image: 14.jpg, Distance: 2.3019, Similar: True, label: 0
# Shot: 12.jpg, Image: 7.jpg, Distance: 2.2966, Similar: True, label: 0
# Shot: 12.jpg, Image: 13.jpg, Distance: 2.6143, Similar: True, label: 0
# Shot: 12.jpg, Image: 15.jpg, Distance: 2.3269, Similar: True, label: 0
# Shot: 12.jpg, Image: 18.jpg, Distance: 1.6620, Similar: True, label: 0
# Shot: 12.jpg, Image: 17.jpg, Distance: 2.3418, Similar: True, label: 0
# Shot: 12.jpg, Image: 16.jpg, Distance: 2.1989, Similar: True, label: 0
# Shot: 7.jpg, Image: 3.jpg, Distance: 1.7890, Similar: True, label: 0
# Shot: 7.jpg, Image: 0.jpg, Distance: 2.1565, Similar: True, label: 0
# Shot: 7.jpg, Image: 1.jpg, Distance: 2.1724, Similar: True, label: 0
# Shot: 7.jpg, Image: 2.jpg, Distance: 2.9387, Similar: True, label: 0
# Shot: 7.jpg, Image: 5.jpg, Distance: 2.4636, Similar: True, label: 0
# Shot: 7.jpg, Image: 4.jpg, Distance: 1.6842, Similar: True, label: 0
# Shot: 7.jpg, Image: 6.jpg, Distance: 2.1824, Similar: True, label: 0
# Shot: 7.jpg, Image: 2.jpg, Distance: 3.6160, Similar: True, label: 0
# Shot: 7.jpg, Image: 3.jpg, Distance: 2.7661, Similar: True, label: 0
# Shot: 7.jpg, Image: 0.jpg, Distance: 4.0848, Similar: True, label: 0
# Shot: 7.jpg, Image: 4.jpg, Distance: 3.6985, Similar: True, label: 0
# Shot: 7.jpg, Image: 1.jpg, Distance: 3.1271, Similar: True, label: 0
# Shot: 7.jpg, Image: 5.jpg, Distance: 3.4909, Similar: True, label: 0
# Shot: 7.jpg, Image: 11.jpg, Distance: 2.8286, Similar: True, label: 0
# Shot: 7.jpg, Image: 8.jpg, Distance: 4.0065, Similar: True, label: 0
# Shot: 7.jpg, Image: 12.jpg, Distance: 2.4396, Similar: True, label: 0
# Shot: 7.jpg, Image: 6.jpg, Distance: 3.7305, Similar: True, label: 0
# Shot: 7.jpg, Image: 9.jpg, Distance: 5.7253, Similar: True, label: 0
# Shot: 7.jpg, Image: 10.jpg, Distance: 3.4497, Similar: True, label: 0
# Shot: 7.jpg, Image: 14.jpg, Distance: 2.8263, Similar: True, label: 0
# Shot: 7.jpg, Image: 7.jpg, Distance: 4.3115, Similar: True, label: 1
# Shot: 7.jpg, Image: 13.jpg, Distance: 4.8486, Similar: True, label: 0
# Shot: 7.jpg, Image: 15.jpg, Distance: 4.1535, Similar: True, label: 0
# Shot: 7.jpg, Image: 18.jpg, Distance: 3.0239, Similar: True, label: 0
# Shot: 7.jpg, Image: 17.jpg, Distance: 3.4997, Similar: True, label: 0
# Shot: 7.jpg, Image: 16.jpg, Distance: 2.4845, Similar: True, label: 0
# Shot: 3.jpg, Image: 3.jpg, Distance: 2.6606, Similar: True, label: 1
# Shot: 3.jpg, Image: 0.jpg, Distance: 3.0633, Similar: True, label: 0
# Shot: 3.jpg, Image: 1.jpg, Distance: 2.8292, Similar: True, label: 0
# Shot: 3.jpg, Image: 2.jpg, Distance: 3.6539, Similar: True, label: 0
# Shot: 3.jpg, Image: 5.jpg, Distance: 4.3782, Similar: True, label: 0
# Shot: 3.jpg, Image: 4.jpg, Distance: 3.0381, Similar: True, label: 0
# Shot: 3.jpg, Image: 6.jpg, Distance: 3.6328, Similar: True, label: 0
# Shot: 3.jpg, Image: 2.jpg, Distance: 5.7504, Similar: True, label: 0
# Shot: 3.jpg, Image: 3.jpg, Distance: 4.5533, Similar: True, label: 1
# Shot: 3.jpg, Image: 0.jpg, Distance: 6.2646, Similar: False, label: 0
# Shot: 3.jpg, Image: 4.jpg, Distance: 5.7002, Similar: True, label: 0
# Shot: 3.jpg, Image: 1.jpg, Distance: 4.7651, Similar: True, label: 0
# Shot: 3.jpg, Image: 5.jpg, Distance: 5.6121, Similar: True, label: 0
# Shot: 3.jpg, Image: 11.jpg, Distance: 4.7080, Similar: True, label: 0
# Shot: 3.jpg, Image: 8.jpg, Distance: 5.9716, Similar: True, label: 0
# Shot: 3.jpg, Image: 12.jpg, Distance: 4.1697, Similar: True, label: 0
# Shot: 3.jpg, Image: 6.jpg, Distance: 5.8363, Similar: True, label: 0
# Shot: 3.jpg, Image: 9.jpg, Distance: 7.8029, Similar: False, label: 0
# Shot: 3.jpg, Image: 10.jpg, Distance: 4.5801, Similar: True, label: 0
# Shot: 3.jpg, Image: 14.jpg, Distance: 4.5223, Similar: True, label: 0
# Shot: 3.jpg, Image: 7.jpg, Distance: 6.5408, Similar: False, label: 0
# Shot: 3.jpg, Image: 13.jpg, Distance: 6.4802, Similar: False, label: 0
# Shot: 3.jpg, Image: 15.jpg, Distance: 6.3931, Similar: False, label: 0
# Shot: 3.jpg, Image: 18.jpg, Distance: 4.9289, Similar: True, label: 0
# Shot: 3.jpg, Image: 17.jpg, Distance: 5.4365, Similar: True, label: 0
# Shot: 3.jpg, Image: 16.jpg, Distance: 4.6805, Similar: True, label: 0
# Shot: 18.jpg, Image: 3.jpg, Distance: 3.0446, Similar: True, label: 0
# Shot: 18.jpg, Image: 0.jpg, Distance: 2.6027, Similar: True, label: 0
# Shot: 18.jpg, Image: 1.jpg, Distance: 2.8639, Similar: True, label: 0
# Shot: 18.jpg, Image: 2.jpg, Distance: 2.6870, Similar: True, label: 0
# Shot: 18.jpg, Image: 5.jpg, Distance: 2.9911, Similar: True, label: 0
# Shot: 18.jpg, Image: 4.jpg, Distance: 2.7532, Similar: True, label: 0
# Shot: 18.jpg, Image: 6.jpg, Distance: 2.1686, Similar: True, label: 0
# Shot: 18.jpg, Image: 2.jpg, Distance: 3.8502, Similar: True, label: 0
# Shot: 18.jpg, Image: 3.jpg, Distance: 3.1374, Similar: True, label: 0
# Shot: 18.jpg, Image: 0.jpg, Distance: 4.0518, Similar: True, label: 0
# Shot: 18.jpg, Image: 4.jpg, Distance: 3.5082, Similar: True, label: 0
# Shot: 18.jpg, Image: 1.jpg, Distance: 2.3072, Similar: True, label: 0
# Shot: 18.jpg, Image: 5.jpg, Distance: 3.9347, Similar: True, label: 0
# Shot: 18.jpg, Image: 11.jpg, Distance: 2.8658, Similar: True, label: 0
# Shot: 18.jpg, Image: 8.jpg, Distance: 3.9085, Similar: True, label: 0
# Shot: 18.jpg, Image: 12.jpg, Distance: 3.7507, Similar: True, label: 0
# Shot: 18.jpg, Image: 6.jpg, Distance: 3.7520, Similar: True, label: 0
# Shot: 18.jpg, Image: 9.jpg, Distance: 5.3569, Similar: True, label: 0
# Shot: 18.jpg, Image: 10.jpg, Distance: 2.1729, Similar: True, label: 0
# Shot: 18.jpg, Image: 14.jpg, Distance: 2.7843, Similar: True, label: 0
# Shot: 18.jpg, Image: 7.jpg, Distance: 4.1703, Similar: True, label: 0
# Shot: 18.jpg, Image: 13.jpg, Distance: 3.8019, Similar: True, label: 0
# Shot: 18.jpg, Image: 15.jpg, Distance: 4.0477, Similar: True, label: 0
# Shot: 18.jpg, Image: 18.jpg, Distance: 3.2065, Similar: True, label: 1
# Shot: 18.jpg, Image: 17.jpg, Distance: 3.6382, Similar: True, label: 0
# Shot: 18.jpg, Image: 16.jpg, Distance: 3.6027, Similar: True, label: 0
# Shot: 2.jpg, Image: 3.jpg, Distance: 1.9274, Similar: True, label: 0
# Shot: 2.jpg, Image: 0.jpg, Distance: 2.2452, Similar: True, label: 0
# Shot: 2.jpg, Image: 1.jpg, Distance: 2.0441, Similar: True, label: 0
# Shot: 2.jpg, Image: 2.jpg, Distance: 2.6393, Similar: True, label: 1
# Shot: 2.jpg, Image: 5.jpg, Distance: 2.9607, Similar: True, label: 0
# Shot: 2.jpg, Image: 4.jpg, Distance: 1.7802, Similar: True, label: 0
# Shot: 2.jpg, Image: 6.jpg, Distance: 2.3278, Similar: True, label: 0
# Shot: 2.jpg, Image: 2.jpg, Distance: 4.5132, Similar: True, label: 1
# Shot: 2.jpg, Image: 3.jpg, Distance: 3.5434, Similar: True, label: 0
# Shot: 2.jpg, Image: 0.jpg, Distance: 5.0022, Similar: True, label: 0
# Shot: 2.jpg, Image: 4.jpg, Distance: 4.4053, Similar: True, label: 0
# Shot: 2.jpg, Image: 1.jpg, Distance: 3.3992, Similar: True, label: 0
# Shot: 2.jpg, Image: 5.jpg, Distance: 4.5633, Similar: True, label: 0
# Shot: 2.jpg, Image: 11.jpg, Distance: 3.2214, Similar: True, label: 0
# Shot: 2.jpg, Image: 8.jpg, Distance: 4.6054, Similar: True, label: 0
# Shot: 2.jpg, Image: 12.jpg, Distance: 3.2958, Similar: True, label: 0
# Shot: 2.jpg, Image: 6.jpg, Distance: 4.5236, Similar: True, label: 0
# Shot: 2.jpg, Image: 9.jpg, Distance: 6.4848, Similar: False, label: 0
# Shot: 2.jpg, Image: 10.jpg, Distance: 3.2987, Similar: True, label: 0
# Shot: 2.jpg, Image: 14.jpg, Distance: 3.3306, Similar: True, label: 0
# Shot: 2.jpg, Image: 7.jpg, Distance: 5.1674, Similar: True, label: 0
# Shot: 2.jpg, Image: 13.jpg, Distance: 5.2051, Similar: True, label: 0
# Shot: 2.jpg, Image: 15.jpg, Distance: 5.0714, Similar: True, label: 0
# Shot: 2.jpg, Image: 18.jpg, Distance: 3.7083, Similar: True, label: 0
# Shot: 2.jpg, Image: 17.jpg, Distance: 4.2306, Similar: True, label: 0
# Shot: 2.jpg, Image: 16.jpg, Distance: 3.5037, Similar: True, label: 0
# Shot: 9.jpg, Image: 3.jpg, Distance: 2.7913, Similar: True, label: 0
# Shot: 9.jpg, Image: 0.jpg, Distance: 2.6155, Similar: True, label: 0
# Shot: 9.jpg, Image: 1.jpg, Distance: 2.8794, Similar: True, label: 0
# Shot: 9.jpg, Image: 2.jpg, Distance: 2.7797, Similar: True, label: 0
# Shot: 9.jpg, Image: 5.jpg, Distance: 2.0619, Similar: True, label: 0
# Shot: 9.jpg, Image: 4.jpg, Distance: 1.9745, Similar: True, label: 0
# Shot: 9.jpg, Image: 6.jpg, Distance: 1.9363, Similar: True, label: 0
# Shot: 9.jpg, Image: 2.jpg, Distance: 3.0246, Similar: True, label: 0
# Shot: 9.jpg, Image: 3.jpg, Distance: 2.6577, Similar: True, label: 0
# Shot: 9.jpg, Image: 0.jpg, Distance: 3.2410, Similar: True, label: 0
# Shot: 9.jpg, Image: 4.jpg, Distance: 2.9074, Similar: True, label: 0
# Shot: 9.jpg, Image: 1.jpg, Distance: 2.4792, Similar: True, label: 0
# Shot: 9.jpg, Image: 5.jpg, Distance: 3.0636, Similar: True, label: 0
# Shot: 9.jpg, Image: 11.jpg, Distance: 1.9006, Similar: True, label: 0
# Shot: 9.jpg, Image: 8.jpg, Distance: 3.0250, Similar: True, label: 0
# Shot: 9.jpg, Image: 12.jpg, Distance: 2.6990, Similar: True, label: 0
# Shot: 9.jpg, Image: 6.jpg, Distance: 3.0171, Similar: True, label: 0
# Shot: 9.jpg, Image: 9.jpg, Distance: 4.6754, Similar: True, label: 1
# Shot: 9.jpg, Image: 10.jpg, Distance: 2.4885, Similar: True, label: 0
# Shot: 9.jpg, Image: 14.jpg, Distance: 2.3189, Similar: True, label: 0
# Shot: 9.jpg, Image: 7.jpg, Distance: 3.3124, Similar: True, label: 0
# Shot: 9.jpg, Image: 13.jpg, Distance: 3.7700, Similar: True, label: 0
# Shot: 9.jpg, Image: 15.jpg, Distance: 3.3224, Similar: True, label: 0
# Shot: 9.jpg, Image: 18.jpg, Distance: 2.5592, Similar: True, label: 0
# Shot: 9.jpg, Image: 17.jpg, Distance: 2.9781, Similar: True, label: 0
# Shot: 9.jpg, Image: 16.jpg, Distance: 2.5940, Similar: True, label: 0
# Shot: 5.jpg, Image: 3.jpg, Distance: 2.5421, Similar: True, label: 0
# Shot: 5.jpg, Image: 0.jpg, Distance: 2.6069, Similar: True, label: 0
# Shot: 5.jpg, Image: 1.jpg, Distance: 2.2792, Similar: True, label: 0
# Shot: 5.jpg, Image: 2.jpg, Distance: 2.8116, Similar: True, label: 0
# Shot: 5.jpg, Image: 5.jpg, Distance: 3.7323, Similar: True, label: 1
# Shot: 5.jpg, Image: 4.jpg, Distance: 2.6439, Similar: True, label: 0
# Shot: 5.jpg, Image: 6.jpg, Distance: 2.8927, Similar: True, label: 0
# Shot: 5.jpg, Image: 2.jpg, Distance: 5.2841, Similar: True, label: 0
# Shot: 5.jpg, Image: 3.jpg, Distance: 4.3164, Similar: True, label: 0
# Shot: 5.jpg, Image: 0.jpg, Distance: 5.4802, Similar: True, label: 0
# Shot: 5.jpg, Image: 4.jpg, Distance: 4.8656, Similar: True, label: 0
# Shot: 5.jpg, Image: 1.jpg, Distance: 3.3980, Similar: True, label: 0
# Shot: 5.jpg, Image: 5.jpg, Distance: 4.9922, Similar: True, label: 1
# Shot: 5.jpg, Image: 11.jpg, Distance: 4.0181, Similar: True, label: 0
# Shot: 5.jpg, Image: 8.jpg, Distance: 5.4156, Similar: True, label: 0
# Shot: 5.jpg, Image: 12.jpg, Distance: 4.3309, Similar: True, label: 0
# Shot: 5.jpg, Image: 6.jpg, Distance: 5.0042, Similar: True, label: 0
# Shot: 5.jpg, Image: 9.jpg, Distance: 7.1964, Similar: False, label: 0
# Shot: 5.jpg, Image: 10.jpg, Distance: 3.8165, Similar: True, label: 0
# Shot: 5.jpg, Image: 14.jpg, Distance: 3.1779, Similar: True, label: 0
# Shot: 5.jpg, Image: 7.jpg, Distance: 5.6493, Similar: True, label: 0
# Shot: 5.jpg, Image: 13.jpg, Distance: 5.7432, Similar: True, label: 0
# Shot: 5.jpg, Image: 15.jpg, Distance: 5.6332, Similar: True, label: 0
# Shot: 5.jpg, Image: 18.jpg, Distance: 4.4096, Similar: True, label: 0
# Shot: 5.jpg, Image: 17.jpg, Distance: 4.8651, Similar: True, label: 0
# Shot: 5.jpg, Image: 16.jpg, Distance: 4.1681, Similar: True, label: 0
# Shot: 17.jpg, Image: 3.jpg, Distance: 2.0939, Similar: True, label: 0
# Shot: 17.jpg, Image: 0.jpg, Distance: 2.1248, Similar: True, label: 0
# Shot: 17.jpg, Image: 1.jpg, Distance: 2.3174, Similar: True, label: 0
# Shot: 17.jpg, Image: 2.jpg, Distance: 2.4411, Similar: True, label: 0
# Shot: 17.jpg, Image: 5.jpg, Distance: 1.8917, Similar: True, label: 0
# Shot: 17.jpg, Image: 4.jpg, Distance: 1.3963, Similar: True, label: 0
# Shot: 17.jpg, Image: 6.jpg, Distance: 1.6790, Similar: True, label: 0
# Shot: 17.jpg, Image: 2.jpg, Distance: 3.0125, Similar: True, label: 0
# Shot: 17.jpg, Image: 3.jpg, Distance: 2.5156, Similar: True, label: 0
# Shot: 17.jpg, Image: 0.jpg, Distance: 3.4412, Similar: True, label: 0
# Shot: 17.jpg, Image: 4.jpg, Distance: 3.1013, Similar: True, label: 0
# Shot: 17.jpg, Image: 1.jpg, Distance: 2.3439, Similar: True, label: 0
# Shot: 17.jpg, Image: 5.jpg, Distance: 3.1050, Similar: True, label: 0
# Shot: 17.jpg, Image: 11.jpg, Distance: 2.0919, Similar: True, label: 0
# Shot: 17.jpg, Image: 8.jpg, Distance: 3.1049, Similar: True, label: 0
# Shot: 17.jpg, Image: 12.jpg, Distance: 2.4587, Similar: True, label: 0
# Shot: 17.jpg, Image: 6.jpg, Distance: 3.1019, Similar: True, label: 0
# Shot: 17.jpg, Image: 9.jpg, Distance: 4.9291, Similar: True, label: 0
# Shot: 17.jpg, Image: 10.jpg, Distance: 2.5130, Similar: True, label: 0
# Shot: 17.jpg, Image: 14.jpg, Distance: 2.2985, Similar: True, label: 0
# Shot: 17.jpg, Image: 7.jpg, Distance: 3.5911, Similar: True, label: 0
# Shot: 17.jpg, Image: 13.jpg, Distance: 3.9334, Similar: True, label: 0
# Shot: 17.jpg, Image: 15.jpg, Distance: 3.4339, Similar: True, label: 0
# Shot: 17.jpg, Image: 18.jpg, Distance: 2.3743, Similar: True, label: 0
# Shot: 17.jpg, Image: 17.jpg, Distance: 2.7971, Similar: True, label: 1
# Shot: 17.jpg, Image: 16.jpg, Distance: 2.3043, Similar: True, label: 0
# Shot: 13.jpg, Image: 3.jpg, Distance: 2.2287, Similar: True, label: 0
# Shot: 13.jpg, Image: 0.jpg, Distance: 2.4959, Similar: True, label: 0
# Shot: 13.jpg, Image: 1.jpg, Distance: 2.7326, Similar: True, label: 0
# Shot: 13.jpg, Image: 2.jpg, Distance: 2.7498, Similar: True, label: 0
# Shot: 13.jpg, Image: 5.jpg, Distance: 2.3706, Similar: True, label: 0
# Shot: 13.jpg, Image: 4.jpg, Distance: 1.9118, Similar: True, label: 0
# Shot: 13.jpg, Image: 6.jpg, Distance: 2.0858, Similar: True, label: 0
# Shot: 13.jpg, Image: 2.jpg, Distance: 3.2147, Similar: True, label: 0
# Shot: 13.jpg, Image: 3.jpg, Distance: 2.6334, Similar: True, label: 0
# Shot: 13.jpg, Image: 0.jpg, Distance: 3.8223, Similar: True, label: 0
# Shot: 13.jpg, Image: 4.jpg, Distance: 3.3097, Similar: True, label: 0
# Shot: 13.jpg, Image: 1.jpg, Distance: 2.8940, Similar: True, label: 0
# Shot: 13.jpg, Image: 5.jpg, Distance: 3.4974, Similar: True, label: 0
# Shot: 13.jpg, Image: 11.jpg, Distance: 2.5854, Similar: True, label: 0
# Shot: 13.jpg, Image: 8.jpg, Distance: 3.5684, Similar: True, label: 0
# Shot: 13.jpg, Image: 12.jpg, Distance: 2.5891, Similar: True, label: 0
# Shot: 13.jpg, Image: 6.jpg, Distance: 3.4183, Similar: True, label: 0
# Shot: 13.jpg, Image: 9.jpg, Distance: 5.2353, Similar: True, label: 0
# Shot: 13.jpg, Image: 10.jpg, Distance: 2.9967, Similar: True, label: 0
# Shot: 13.jpg, Image: 14.jpg, Distance: 2.7726, Similar: True, label: 0
# Shot: 13.jpg, Image: 7.jpg, Distance: 3.8739, Similar: True, label: 0
# Shot: 13.jpg, Image: 13.jpg, Distance: 4.1997, Similar: True, label: 1
# Shot: 13.jpg, Image: 15.jpg, Distance: 3.7357, Similar: True, label: 0
# Shot: 13.jpg, Image: 18.jpg, Distance: 2.9078, Similar: True, label: 0
# Shot: 13.jpg, Image: 17.jpg, Distance: 3.3500, Similar: True, label: 0
# Shot: 13.jpg, Image: 16.jpg, Distance: 2.5618, Similar: True, label: 0
# Shot: 4.jpg, Image: 3.jpg, Distance: 1.9931, Similar: True, label: 0
# Shot: 4.jpg, Image: 0.jpg, Distance: 1.9227, Similar: True, label: 0
# Shot: 4.jpg, Image: 1.jpg, Distance: 2.0745, Similar: True, label: 0
# Shot: 4.jpg, Image: 2.jpg, Distance: 2.3262, Similar: True, label: 0
# Shot: 4.jpg, Image: 5.jpg, Distance: 1.9493, Similar: True, label: 0
# Shot: 4.jpg, Image: 4.jpg, Distance: 1.5401, Similar: True, label: 1
# Shot: 4.jpg, Image: 6.jpg, Distance: 1.5291, Similar: True, label: 0
# Shot: 4.jpg, Image: 2.jpg, Distance: 3.1662, Similar: True, label: 0
# Shot: 4.jpg, Image: 3.jpg, Distance: 2.3419, Similar: True, label: 0
# Shot: 4.jpg, Image: 0.jpg, Distance: 3.5429, Similar: True, label: 0
# Shot: 4.jpg, Image: 4.jpg, Distance: 3.0785, Similar: True, label: 1
# Shot: 4.jpg, Image: 1.jpg, Distance: 2.2998, Similar: True, label: 0
# Shot: 4.jpg, Image: 5.jpg, Distance: 3.1771, Similar: True, label: 0
# Shot: 4.jpg, Image: 11.jpg, Distance: 2.0720, Similar: True, label: 0
# Shot: 4.jpg, Image: 8.jpg, Distance: 3.3194, Similar: True, label: 0
# Shot: 4.jpg, Image: 12.jpg, Distance: 2.4445, Similar: True, label: 0
# Shot: 4.jpg, Image: 6.jpg, Distance: 3.1392, Similar: True, label: 0
# Shot: 4.jpg, Image: 9.jpg, Distance: 5.0873, Similar: True, label: 0
# Shot: 4.jpg, Image: 10.jpg, Distance: 2.1617, Similar: True, label: 0
# Shot: 4.jpg, Image: 14.jpg, Distance: 2.3185, Similar: True, label: 0
# Shot: 4.jpg, Image: 7.jpg, Distance: 3.7703, Similar: True, label: 0
# Shot: 4.jpg, Image: 13.jpg, Distance: 3.8377, Similar: True, label: 0
# Shot: 4.jpg, Image: 15.jpg, Distance: 3.6107, Similar: True, label: 0
# Shot: 4.jpg, Image: 18.jpg, Distance: 2.4086, Similar: True, label: 0
# Shot: 4.jpg, Image: 17.jpg, Distance: 3.1074, Similar: True, label: 0
# Shot: 4.jpg, Image: 16.jpg, Distance: 2.4526, Similar: True, label: 0
# Shot: 6.jpg, Image: 3.jpg, Distance: 1.9828, Similar: True, label: 0
# Shot: 6.jpg, Image: 0.jpg, Distance: 1.9345, Similar: True, label: 0
# Shot: 6.jpg, Image: 1.jpg, Distance: 2.0936, Similar: True, label: 0
# Shot: 6.jpg, Image: 2.jpg, Distance: 2.4531, Similar: True, label: 0
# Shot: 6.jpg, Image: 5.jpg, Distance: 2.2105, Similar: True, label: 0
# Shot: 6.jpg, Image: 4.jpg, Distance: 1.5865, Similar: True, label: 0
# Shot: 6.jpg, Image: 6.jpg, Distance: 1.7315, Similar: True, label: 1
# Shot: 6.jpg, Image: 2.jpg, Distance: 3.3480, Similar: True, label: 0
# Shot: 6.jpg, Image: 3.jpg, Distance: 2.5861, Similar: True, label: 0
# Shot: 6.jpg, Image: 0.jpg, Distance: 3.7653, Similar: True, label: 0
# Shot: 6.jpg, Image: 4.jpg, Distance: 3.3847, Similar: True, label: 0
# Shot: 6.jpg, Image: 1.jpg, Distance: 2.5554, Similar: True, label: 0
# Shot: 6.jpg, Image: 5.jpg, Distance: 3.3320, Similar: True, label: 0
# Shot: 6.jpg, Image: 11.jpg, Distance: 2.3021, Similar: True, label: 0
# Shot: 6.jpg, Image: 8.jpg, Distance: 3.4681, Similar: True, label: 0
# Shot: 6.jpg, Image: 12.jpg, Distance: 2.5259, Similar: True, label: 0
# Shot: 6.jpg, Image: 6.jpg, Distance: 3.3679, Similar: True, label: 1
# Shot: 6.jpg, Image: 9.jpg, Distance: 5.3243, Similar: True, label: 0
# Shot: 6.jpg, Image: 10.jpg, Distance: 2.5585, Similar: True, label: 0
# Shot: 6.jpg, Image: 14.jpg, Distance: 2.4231, Similar: True, label: 0
# Shot: 6.jpg, Image: 7.jpg, Distance: 3.9995, Similar: True, label: 0
# Shot: 6.jpg, Image: 13.jpg, Distance: 4.1813, Similar: True, label: 0
# Shot: 6.jpg, Image: 15.jpg, Distance: 3.8455, Similar: True, label: 0
# Shot: 6.jpg, Image: 18.jpg, Distance: 2.6263, Similar: True, label: 0
# Shot: 6.jpg, Image: 17.jpg, Distance: 3.2252, Similar: True, label: 0
# Shot: 6.jpg, Image: 16.jpg, Distance: 2.6544, Similar: True, label: 0
# Shot: 0.jpg, Image: 3.jpg, Distance: 3.1190, Similar: True, label: 0
# Shot: 0.jpg, Image: 0.jpg, Distance: 2.8216, Similar: True, label: 1
# Shot: 0.jpg, Image: 1.jpg, Distance: 3.0795, Similar: True, label: 0
# Shot: 0.jpg, Image: 2.jpg, Distance: 3.2580, Similar: True, label: 0
# Shot: 0.jpg, Image: 5.jpg, Distance: 2.4906, Similar: True, label: 0
# Shot: 0.jpg, Image: 4.jpg, Distance: 2.7740, Similar: True, label: 0
# Shot: 0.jpg, Image: 6.jpg, Distance: 2.3502, Similar: True, label: 0
# Shot: 0.jpg, Image: 2.jpg, Distance: 2.6971, Similar: True, label: 0
# Shot: 0.jpg, Image: 3.jpg, Distance: 2.3889, Similar: True, label: 0
# Shot: 0.jpg, Image: 0.jpg, Distance: 2.6200, Similar: True, label: 1
# Shot: 0.jpg, Image: 4.jpg, Distance: 2.4647, Similar: True, label: 0
# Shot: 0.jpg, Image: 1.jpg, Distance: 2.4225, Similar: True, label: 0
# Shot: 0.jpg, Image: 5.jpg, Distance: 2.4119, Similar: True, label: 0
# Shot: 0.jpg, Image: 11.jpg, Distance: 2.2763, Similar: True, label: 0
# Shot: 0.jpg, Image: 8.jpg, Distance: 3.0021, Similar: True, label: 0
# Shot: 0.jpg, Image: 12.jpg, Distance: 2.7401, Similar: True, label: 0
# Shot: 0.jpg, Image: 6.jpg, Distance: 2.6459, Similar: True, label: 0
# Shot: 0.jpg, Image: 9.jpg, Distance: 4.3878, Similar: True, label: 0
# Shot: 0.jpg, Image: 10.jpg, Distance: 2.7878, Similar: True, label: 0
# Shot: 0.jpg, Image: 14.jpg, Distance: 2.2622, Similar: True, label: 0
# Shot: 0.jpg, Image: 7.jpg, Distance: 2.8867, Similar: True, label: 0
# Shot: 0.jpg, Image: 13.jpg, Distance: 3.5579, Similar: True, label: 0
# Shot: 0.jpg, Image: 15.jpg, Distance: 2.8807, Similar: True, label: 0
# Shot: 0.jpg, Image: 18.jpg, Distance: 2.3326, Similar: True, label: 0
# Shot: 0.jpg, Image: 17.jpg, Distance: 2.8649, Similar: True, label: 0
# Shot: 0.jpg, Image: 16.jpg, Distance: 2.3565, Similar: True, label: 0
# Shot: 10.jpg, Image: 3.jpg, Distance: 2.1733, Similar: True, label: 0
# Shot: 10.jpg, Image: 0.jpg, Distance: 1.9210, Similar: True, label: 0
# Shot: 10.jpg, Image: 1.jpg, Distance: 2.0179, Similar: True, label: 0
# Shot: 10.jpg, Image: 2.jpg, Distance: 2.0761, Similar: True, label: 0
# Shot: 10.jpg, Image: 5.jpg, Distance: 3.1079, Similar: True, label: 0
# Shot: 10.jpg, Image: 4.jpg, Distance: 2.0686, Similar: True, label: 0
# Shot: 10.jpg, Image: 6.jpg, Distance: 2.2018, Similar: True, label: 0
# Shot: 10.jpg, Image: 2.jpg, Distance: 4.0348, Similar: True, label: 0
# Shot: 10.jpg, Image: 3.jpg, Distance: 3.2666, Similar: True, label: 0
# Shot: 10.jpg, Image: 0.jpg, Distance: 4.4345, Similar: True, label: 0
# Shot: 10.jpg, Image: 4.jpg, Distance: 3.9717, Similar: True, label: 0
# Shot: 10.jpg, Image: 1.jpg, Distance: 2.4986, Similar: True, label: 0
# Shot: 10.jpg, Image: 5.jpg, Distance: 4.0265, Similar: True, label: 0
# Shot: 10.jpg, Image: 11.jpg, Distance: 3.2528, Similar: True, label: 0
# Shot: 10.jpg, Image: 8.jpg, Distance: 4.1331, Similar: True, label: 0
# Shot: 10.jpg, Image: 12.jpg, Distance: 3.5936, Similar: True, label: 0
# Shot: 10.jpg, Image: 6.jpg, Distance: 3.9864, Similar: True, label: 0
# Shot: 10.jpg, Image: 9.jpg, Distance: 5.9852, Similar: True, label: 0
# Shot: 10.jpg, Image: 10.jpg, Distance: 2.6624, Similar: True, label: 1
# Shot: 10.jpg, Image: 14.jpg, Distance: 2.7435, Similar: True, label: 0
# Shot: 10.jpg, Image: 7.jpg, Distance: 4.6700, Similar: True, label: 0
# Shot: 10.jpg, Image: 13.jpg, Distance: 4.3752, Similar: True, label: 0
# Shot: 10.jpg, Image: 15.jpg, Distance: 4.5500, Similar: True, label: 0
# Shot: 10.jpg, Image: 18.jpg, Distance: 3.1588, Similar: True, label: 0
# Shot: 10.jpg, Image: 17.jpg, Distance: 3.6238, Similar: True, label: 0
# Shot: 10.jpg, Image: 16.jpg, Distance: 3.3927, Similar: True, label: 0
# Shot: 1.jpg, Image: 3.jpg, Distance: 2.7450, Similar: True, label: 0
# Shot: 1.jpg, Image: 0.jpg, Distance: 2.3281, Similar: True, label: 0
# Shot: 1.jpg, Image: 1.jpg, Distance: 2.5778, Similar: True, label: 1
# Shot: 1.jpg, Image: 2.jpg, Distance: 2.4298, Similar: True, label: 0
# Shot: 1.jpg, Image: 5.jpg, Distance: 2.8976, Similar: True, label: 0
# Shot: 1.jpg, Image: 4.jpg, Distance: 2.5426, Similar: True, label: 0
# Shot: 1.jpg, Image: 6.jpg, Distance: 2.1023, Similar: True, label: 0
# Shot: 1.jpg, Image: 2.jpg, Distance: 3.7190, Similar: True, label: 0
# Shot: 1.jpg, Image: 3.jpg, Distance: 3.0607, Similar: True, label: 0
# Shot: 1.jpg, Image: 0.jpg, Distance: 3.9273, Similar: True, label: 0
# Shot: 1.jpg, Image: 4.jpg, Distance: 3.4038, Similar: True, label: 0
# Shot: 1.jpg, Image: 1.jpg, Distance: 2.0837, Similar: True, label: 1
# Shot: 1.jpg, Image: 5.jpg, Distance: 3.6234, Similar: True, label: 0
# Shot: 1.jpg, Image: 11.jpg, Distance: 2.8356, Similar: True, label: 0
# Shot: 1.jpg, Image: 8.jpg, Distance: 3.8693, Similar: True, label: 0
# Shot: 1.jpg, Image: 12.jpg, Distance: 3.6114, Similar: True, label: 0
# Shot: 1.jpg, Image: 6.jpg, Distance: 3.6291, Similar: True, label: 0
# Shot: 1.jpg, Image: 9.jpg, Distance: 5.5393, Similar: True, label: 0
# Shot: 1.jpg, Image: 10.jpg, Distance: 2.3814, Similar: True, label: 0
# Shot: 1.jpg, Image: 14.jpg, Distance: 2.0582, Similar: True, label: 0
# Shot: 1.jpg, Image: 7.jpg, Distance: 4.1007, Similar: True, label: 0
# Shot: 1.jpg, Image: 13.jpg, Distance: 3.9409, Similar: True, label: 0
# Shot: 1.jpg, Image: 15.jpg, Distance: 4.0188, Similar: True, label: 0
# Shot: 1.jpg, Image: 18.jpg, Distance: 3.1878, Similar: True, label: 0
# Shot: 1.jpg, Image: 17.jpg, Distance: 3.5421, Similar: True, label: 0
# Shot: 1.jpg, Image: 16.jpg, Distance: 3.3601, Similar: True, label: 0
# Shot: 8.jpg, Image: 3.jpg, Distance: 2.7462, Similar: True, label: 0
# Shot: 8.jpg, Image: 0.jpg, Distance: 2.1929, Similar: True, label: 0
# Shot: 8.jpg, Image: 1.jpg, Distance: 2.4010, Similar: True, label: 0
# Shot: 8.jpg, Image: 2.jpg, Distance: 2.6125, Similar: True, label: 0
# Shot: 8.jpg, Image: 5.jpg, Distance: 3.3781, Similar: True, label: 0
# Shot: 8.jpg, Image: 4.jpg, Distance: 2.6706, Similar: True, label: 0
# Shot: 8.jpg, Image: 6.jpg, Distance: 2.2466, Similar: True, label: 0
# Shot: 8.jpg, Image: 2.jpg, Distance: 4.2096, Similar: True, label: 0
# Shot: 8.jpg, Image: 3.jpg, Distance: 3.3604, Similar: True, label: 0
# Shot: 8.jpg, Image: 0.jpg, Distance: 4.4532, Similar: True, label: 0
# Shot: 8.jpg, Image: 4.jpg, Distance: 3.9872, Similar: True, label: 0
# Shot: 8.jpg, Image: 1.jpg, Distance: 2.4011, Similar: True, label: 0
# Shot: 8.jpg, Image: 5.jpg, Distance: 4.2289, Similar: True, label: 0
# Shot: 8.jpg, Image: 11.jpg, Distance: 3.2971, Similar: True, label: 0
# Shot: 8.jpg, Image: 8.jpg, Distance: 4.2252, Similar: True, label: 1
# Shot: 8.jpg, Image: 12.jpg, Distance: 3.8620, Similar: True, label: 0
# Shot: 8.jpg, Image: 6.jpg, Distance: 4.1368, Similar: True, label: 0
# Shot: 8.jpg, Image: 9.jpg, Distance: 5.8815, Similar: True, label: 0
# Shot: 8.jpg, Image: 10.jpg, Distance: 2.5207, Similar: True, label: 0
# Shot: 8.jpg, Image: 14.jpg, Distance: 3.0085, Similar: True, label: 0
# Shot: 8.jpg, Image: 7.jpg, Distance: 4.6642, Similar: True, label: 0
# Shot: 8.jpg, Image: 13.jpg, Distance: 4.2410, Similar: True, label: 0
# Shot: 8.jpg, Image: 15.jpg, Distance: 4.5232, Similar: True, label: 0
# Shot: 8.jpg, Image: 18.jpg, Distance: 3.3981, Similar: True, label: 0
# Shot: 8.jpg, Image: 17.jpg, Distance: 3.8422, Similar: True, label: 0
# Shot: 8.jpg, Image: 16.jpg, Distance: 3.8190, Similar: True, label: 0
# Shot: 11.jpg, Image: 3.jpg, Distance: 2.2753, Similar: True, label: 0
# Shot: 11.jpg, Image: 0.jpg, Distance: 2.0928, Similar: True, label: 0
# Shot: 11.jpg, Image: 1.jpg, Distance: 2.1699, Similar: True, label: 0
# Shot: 11.jpg, Image: 2.jpg, Distance: 2.3196, Similar: True, label: 0
# Shot: 11.jpg, Image: 5.jpg, Distance: 3.5056, Similar: True, label: 0
# Shot: 11.jpg, Image: 4.jpg, Distance: 2.4741, Similar: True, label: 0
# Shot: 11.jpg, Image: 6.jpg, Distance: 2.3949, Similar: True, label: 0
# Shot: 11.jpg, Image: 2.jpg, Distance: 4.2877, Similar: True, label: 0
# Shot: 11.jpg, Image: 3.jpg, Distance: 3.3533, Similar: True, label: 0
# Shot: 11.jpg, Image: 0.jpg, Distance: 4.6310, Similar: True, label: 0
# Shot: 11.jpg, Image: 4.jpg, Distance: 4.1523, Similar: True, label: 0
# Shot: 11.jpg, Image: 1.jpg, Distance: 2.5649, Similar: True, label: 0
# Shot: 11.jpg, Image: 5.jpg, Distance: 4.1784, Similar: True, label: 0
# Shot: 11.jpg, Image: 11.jpg, Distance: 3.5933, Similar: True, label: 1
# Shot: 11.jpg, Image: 8.jpg, Distance: 4.4158, Similar: True, label: 0
# Shot: 11.jpg, Image: 12.jpg, Distance: 3.8141, Similar: True, label: 0
# Shot: 11.jpg, Image: 6.jpg, Distance: 4.2617, Similar: True, label: 0
# Shot: 11.jpg, Image: 9.jpg, Distance: 6.1938, Similar: False, label: 0
# Shot: 11.jpg, Image: 10.jpg, Distance: 2.9609, Similar: True, label: 0
# Shot: 11.jpg, Image: 14.jpg, Distance: 2.9960, Similar: True, label: 0
# Shot: 11.jpg, Image: 7.jpg, Distance: 4.8758, Similar: True, label: 0
# Shot: 11.jpg, Image: 13.jpg, Distance: 4.4704, Similar: True, label: 0
# Shot: 11.jpg, Image: 15.jpg, Distance: 4.7792, Similar: True, label: 0
# Shot: 11.jpg, Image: 18.jpg, Distance: 3.4505, Similar: True, label: 0
# Shot: 11.jpg, Image: 17.jpg, Distance: 3.8135, Similar: True, label: 0
# Shot: 11.jpg, Image: 16.jpg, Distance: 3.6223, Similar: True, label: 0
# Shot: 16.jpg, Image: 3.jpg, Distance: 2.1088, Similar: True, label: 0
# Shot: 16.jpg, Image: 0.jpg, Distance: 2.5781, Similar: True, label: 0
# Shot: 16.jpg, Image: 1.jpg, Distance: 2.3662, Similar: True, label: 0
# Shot: 16.jpg, Image: 2.jpg, Distance: 2.6558, Similar: True, label: 0
# Shot: 16.jpg, Image: 5.jpg, Distance: 3.1405, Similar: True, label: 0
# Shot: 16.jpg, Image: 4.jpg, Distance: 1.9553, Similar: True, label: 0
# Shot: 16.jpg, Image: 6.jpg, Distance: 2.7645, Similar: True, label: 0
# Shot: 16.jpg, Image: 2.jpg, Distance: 4.6725, Similar: True, label: 0
# Shot: 16.jpg, Image: 3.jpg, Distance: 3.9349, Similar: True, label: 0
# Shot: 16.jpg, Image: 0.jpg, Distance: 5.2222, Similar: True, label: 0
# Shot: 16.jpg, Image: 4.jpg, Distance: 4.7841, Similar: True, label: 0
# Shot: 16.jpg, Image: 1.jpg, Distance: 3.5819, Similar: True, label: 0
# Shot: 16.jpg, Image: 5.jpg, Distance: 4.7744, Similar: True, label: 0
# Shot: 16.jpg, Image: 11.jpg, Distance: 3.5663, Similar: True, label: 0
# Shot: 16.jpg, Image: 8.jpg, Distance: 4.7129, Similar: True, label: 0
# Shot: 16.jpg, Image: 12.jpg, Distance: 3.7267, Similar: True, label: 0
# Shot: 16.jpg, Image: 6.jpg, Distance: 4.7512, Similar: True, label: 0
# Shot: 16.jpg, Image: 9.jpg, Distance: 6.7629, Similar: False, label: 0
# Shot: 16.jpg, Image: 10.jpg, Distance: 3.6146, Similar: True, label: 0
# Shot: 16.jpg, Image: 14.jpg, Distance: 3.4499, Similar: True, label: 0
# Shot: 16.jpg, Image: 7.jpg, Distance: 5.3339, Similar: True, label: 0
# Shot: 16.jpg, Image: 13.jpg, Distance: 5.4994, Similar: True, label: 0
# Shot: 16.jpg, Image: 15.jpg, Distance: 5.2588, Similar: True, label: 0
# Shot: 16.jpg, Image: 18.jpg, Distance: 3.9492, Similar: True, label: 0
# Shot: 16.jpg, Image: 17.jpg, Distance: 4.4055, Similar: True, label: 0
# Shot: 16.jpg, Image: 16.jpg, Distance: 3.7612, Similar: True, label: 1
# Shot: 14.jpg, Image: 3.jpg, Distance: 2.6457, Similar: True, label: 0
# Shot: 14.jpg, Image: 0.jpg, Distance: 2.6660, Similar: True, label: 0
# Shot: 14.jpg, Image: 1.jpg, Distance: 2.2676, Similar: True, label: 0
# Shot: 14.jpg, Image: 2.jpg, Distance: 3.2552, Similar: True, label: 0
# Shot: 14.jpg, Image: 5.jpg, Distance: 4.4159, Similar: True, label: 0
# Shot: 14.jpg, Image: 4.jpg, Distance: 3.1698, Similar: True, label: 0
# Shot: 14.jpg, Image: 6.jpg, Distance: 3.4646, Similar: True, label: 0
# Shot: 14.jpg, Image: 2.jpg, Distance: 5.8712, Similar: True, label: 0
# Shot: 14.jpg, Image: 3.jpg, Distance: 4.5763, Similar: True, label: 0
# Shot: 14.jpg, Image: 0.jpg, Distance: 6.1530, Similar: False, label: 0
# Shot: 14.jpg, Image: 4.jpg, Distance: 5.4818, Similar: True, label: 0
# Shot: 14.jpg, Image: 1.jpg, Distance: 4.0610, Similar: True, label: 0
# Shot: 14.jpg, Image: 5.jpg, Distance: 5.5203, Similar: True, label: 0
# Shot: 14.jpg, Image: 11.jpg, Distance: 4.8291, Similar: True, label: 0
# Shot: 14.jpg, Image: 8.jpg, Distance: 6.1053, Similar: False, label: 0
# Shot: 14.jpg, Image: 12.jpg, Distance: 4.6200, Similar: True, label: 0
# Shot: 14.jpg, Image: 6.jpg, Distance: 5.6373, Similar: True, label: 0
# Shot: 14.jpg, Image: 9.jpg, Distance: 7.9242, Similar: False, label: 0
# Shot: 14.jpg, Image: 10.jpg, Distance: 4.0408, Similar: True, label: 0
# Shot: 14.jpg, Image: 14.jpg, Distance: 3.9943, Similar: True, label: 1
# Shot: 14.jpg, Image: 7.jpg, Distance: 6.4044, Similar: False, label: 0
# Shot: 14.jpg, Image: 13.jpg, Distance: 6.1684, Similar: False, label: 0
# Shot: 14.jpg, Image: 15.jpg, Distance: 6.2945, Similar: False, label: 0
# Shot: 14.jpg, Image: 18.jpg, Distance: 4.9823, Similar: True, label: 0
# Shot: 14.jpg, Image: 17.jpg, Distance: 5.6134, Similar: True, label: 0
# Shot: 14.jpg, Image: 16.jpg, Distance: 4.7190, Similar: True, label: 0
# Shot: 15.jpg, Image: 3.jpg, Distance: 2.3120, Similar: True, label: 0
# Shot: 15.jpg, Image: 0.jpg, Distance: 2.1697, Similar: True, label: 0
# Shot: 15.jpg, Image: 1.jpg, Distance: 2.4779, Similar: True, label: 0
# Shot: 15.jpg, Image: 2.jpg, Distance: 2.4009, Similar: True, label: 0
# Shot: 15.jpg, Image: 5.jpg, Distance: 2.2943, Similar: True, label: 0
# Shot: 15.jpg, Image: 4.jpg, Distance: 1.9252, Similar: True, label: 0
# Shot: 15.jpg, Image: 6.jpg, Distance: 1.6112, Similar: True, label: 0
# Shot: 15.jpg, Image: 2.jpg, Distance: 2.9345, Similar: True, label: 0
# Shot: 15.jpg, Image: 3.jpg, Distance: 2.1677, Similar: True, label: 0
# Shot: 15.jpg, Image: 0.jpg, Distance: 3.2469, Similar: True, label: 0
# Shot: 15.jpg, Image: 4.jpg, Distance: 2.6586, Similar: True, label: 0
# Shot: 15.jpg, Image: 1.jpg, Distance: 2.2810, Similar: True, label: 0
# Shot: 15.jpg, Image: 5.jpg, Distance: 2.8902, Similar: True, label: 0
# Shot: 15.jpg, Image: 11.jpg, Distance: 2.2981, Similar: True, label: 0
# Shot: 15.jpg, Image: 8.jpg, Distance: 3.2916, Similar: True, label: 0
# Shot: 15.jpg, Image: 12.jpg, Distance: 2.3452, Similar: True, label: 0
# Shot: 15.jpg, Image: 6.jpg, Distance: 2.8937, Similar: True, label: 0
# Shot: 15.jpg, Image: 9.jpg, Distance: 4.8850, Similar: True, label: 0
# Shot: 15.jpg, Image: 10.jpg, Distance: 2.3881, Similar: True, label: 0
# Shot: 15.jpg, Image: 14.jpg, Distance: 2.0067, Similar: True, label: 0
# Shot: 15.jpg, Image: 7.jpg, Distance: 3.2887, Similar: True, label: 0
# Shot: 15.jpg, Image: 13.jpg, Distance: 3.5358, Similar: True, label: 0
# Shot: 15.jpg, Image: 15.jpg, Distance: 3.3600, Similar: True, label: 1
# Shot: 15.jpg, Image: 18.jpg, Distance: 2.5164, Similar: True, label: 0
# Shot: 15.jpg, Image: 17.jpg, Distance: 3.1613, Similar: True, label: 0
# Shot: 15.jpg, Image: 16.jpg, Distance: 2.3367, Similar: True, label: 0

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import models, transforms
import cv2
import os

# image transformations
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# get all files from directories and subdirectories
def get_all_files(dir_path):
    all_files = []
    for root, _, files in os.walk(dir_path):
        for file in files:
            if file.endswith(('jpg', 'jpeg', 'png')):
                all_files.append(os.path.join(root, file))
    return all_files

# Define the Siamese Network
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        self.convnext = models.convnext_base(weights='IMAGENET1K_V1')

        # Freeze all layers except the classifier
        for param in self.convnext.parameters():
            param.requires_grad = False

        # Modify the fully connected layer
        self.convnext.classifier[2] = nn.Linear(self.convnext.classifier[2].in_features, 512)

    def forward_one(self, x):
        x = self.convnext(x)
        return x

    def forward(self, input1, input2):
        output1 = self.forward_one(input1)
        output2 = self.forward_one(input2)
        return output1, output2

# Define the dataset for image pairs
class ImagePairDataset(Dataset):
    def __init__(self, image_dir, shots_dir, transform=None):
        self.image_dir = image_dir
        self.shots_dir = shots_dir
        self.transform = transform
        self.image_pairs = []
        self.labels = []
        self._prepare_data()

    def _prepare_data(self):
        shots_files = get_all_files(self.shots_dir)
        image_files = get_all_files(self.image_dir)

        print(f"Number of shots: {len(shots_files)}")
        print(f"Number of images in anonymized dataset: {len(image_files)}")

        for shot_path in shots_files:
            for img_path in image_files:
                shot_id = os.path.basename(os.path.dirname(shot_path))
                img_id = os.path.basename(os.path.dirname(img_path))

                # Label 1 if they are from the same person, otherwise 0
                label = 1 if shot_id == img_id else 0
                self.image_pairs.append((shot_path, img_path))
                self.labels.append(label)

        print(f"Total image pairs created: {len(self.image_pairs)}")

    def __len__(self):
        return len(self.image_pairs)

    def __getitem__(self, idx):
        image1_path, image2_path = self.image_pairs[idx]
        image1 = cv2.imread(image1_path)
        image2 = cv2.imread(image2_path)
        image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
        image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

        if self.transform:
            image1 = self.transform(image1)
            image2 = self.transform(image2)

        label = torch.tensor(self.labels[idx], dtype=torch.float32)
        return image1, image2, label

# compute the Euclidean distance
def euclidean_distance(a, b):
    return F.pairwise_distance(a, b)

# Training
def train(model, dataloader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    for image1, image2, label in dataloader:
        image1, image2, label = image1.to(device), image2.to(device), label.to(device)
        optimizer.zero_grad()
        output1, output2 = model(image1, image2)
        loss = criterion(euclidean_distance(output1, output2), label)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    return running_loss / len(dataloader)

# Evaluation function
def evaluate(model, dataloader, threshold, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for image1, image2, label in dataloader:
            image1, image2, label = image1.to(device), image2.to(device), label.to(device)
            output1, output2 = model(image1, image2)
            distance = euclidean_distance(output1, output2)
            predictions = (distance < threshold).float()
            correct += (predictions == label).sum().item()
            total += label.size(0)
    return correct / total

# classify similarity of shots with anonymized dataset
def classify_similarity(model, shots_dir, image_dir, threshold, device):
    model.eval()
    transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
    ])

    shots_files = get_all_files(shots_dir)
    image_files = get_all_files(image_dir)
    results = []

    with torch.no_grad():
        for shot_path in shots_files:
            shot_id = os.path.basename(os.path.dirname(shot_path))
            shot_name = os.path.basename(shot_path)
            shot_image = cv2.imread(shot_path)
            shot_image = cv2.cvtColor(shot_image, cv2.COLOR_BGR2RGB)
            shot_image = transform(shot_image).unsqueeze(0).to(device)

            for img_path in image_files:
                img_id = os.path.basename(os.path.dirname(img_path))
                img_name = os.path.basename(img_path)
                img_image = cv2.imread(img_path)
                img_image = cv2.cvtColor(img_image, cv2.COLOR_BGR2RGB)
                img_image = transform(img_image).unsqueeze(0).to(device)
                # label = 1 if shot_image == image_files else 0
                label = 1 if shot_id == img_id else 0
                output1, output2 = model(shot_image, img_image)
                distance = euclidean_distance(output1, output2).item()
                similar = distance < threshold
                results.append((shot_name, img_name, distance, similar))

                # Print shot name, image name, and similarity status
                if similar:
                    print(f"Shot: {shot_name}, Image: {img_name}, Distance: {distance:.4f}, Similar: True, label: {label}")
                else:
                    print(f"Shot: {shot_name}, Image: {img_name}, Distance: {distance:.4f}, Similar: False, label: {label}")

    return results

# Main function
def main(image_dir, shots_dir, batch_size=16, num_epochs=500, learning_rate=0.001, threshold=6.0):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    dataset = ImagePairDataset(image_dir, shots_dir, transform=transform)

    if len(dataset) == 0:
        print("No image pairs found. Please check the dataset paths and image files.")
        return

    train_size = int(0.8 * len(dataset))
    test_size = len(dataset) - train_size

    if train_size == 0 or test_size == 0:
        print(f"Train size: {train_size}, Test size: {test_size}. Not enough data to split.")
        return

    train_dataset, test_dataset = random_split(dataset, [train_size, test_size])
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    model = SiameseNetwork().to(device)
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.Adam(model.convnext.classifier[2].parameters(), lr=learning_rate)

    for epoch in range(num_epochs):
        train_loss = train(model, train_loader, criterion, optimizer, device)
        test_accuracy = evaluate(model, test_loader, threshold, device)
        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {train_loss:.4f}, Accuracy: {test_accuracy:.4f}")

    print("Training complete")
    torch.save(model.state_dict(), "/content/drive/MyDrive/urv/distance_model_covnext.pt")
    # Final test evaluation
    final_test_accuracy = evaluate(model, test_loader, threshold, device)
    print(f"Final Test Accuracy: {final_test_accuracy:.4f}")

    # Classify similarity
    classify_similarity(model, shots_dir, image_dir, threshold, device)

# Example usage
image_dir = '/content/drive/MyDrive/urv/Images_For_The_Person_i_Want_To_Identify_In_Anonymized_Dataset_with_noise'
shots_dir = '/content/drive/MyDrive/urv/Images_For_The_Person_i_Want_To_Identify_In_Anonymized_Dataset_without_noise'
main(image_dir, shots_dir)
# Out:
# Number of shots: 26
# Number of images in anonymized dataset: 26
# Total image pairs created: 676
# Epoch [1/500], Loss: 1.3513, Accuracy: 0.6544
# Epoch [2/500], Loss: 1.0521, Accuracy: 0.6544
# Epoch [3/500], Loss: 1.0096, Accuracy: 0.6544
# Epoch [4/500], Loss: 0.9836, Accuracy: 0.6544
# Epoch [5/500], Loss: 0.9713, Accuracy: 0.6544
# Epoch [6/500], Loss: 0.9711, Accuracy: 0.6544
# Epoch [7/500], Loss: 0.9285, Accuracy: 0.6544
# Epoch [8/500], Loss: 0.9208, Accuracy: 0.6544
# Epoch [9/500], Loss: 0.9352, Accuracy: 0.6544
# Epoch [10/500], Loss: 0.9186, Accuracy: 0.6544
# Epoch [11/500], Loss: 0.9120, Accuracy: 0.6544
# Epoch [12/500], Loss: 0.8845, Accuracy: 0.6544
# Epoch [13/500], Loss: 0.8996, Accuracy: 0.6544
# Epoch [14/500], Loss: 0.8699, Accuracy: 0.6544
# Epoch [15/500], Loss: 0.8581, Accuracy: 0.6544
# Epoch [16/500], Loss: 0.8589, Accuracy: 0.6544
# Epoch [17/500], Loss: 0.8902, Accuracy: 0.6544
